# %% [markdown]
# # ASSIGNMENT 4
# # Submission Deadline: 16/03/2026, 11:59 PM
# # Submission Link: [https://forms.gle/WQzN4N7vAyGycjPaA](https://forms.gle/WQzN4N7vAyGycjPaA)

# %% [markdown]
# # Table of Contents
#
# 1. [Provide Information](#Provide-Information)
# 2. [Instructions](#Instructions)
# 3. [Environment](#Environment)
# 4. [Hyperparameters](#Hyperparameters)
# 5. [Helper Functions](#helper)
# 6. [Deep Value Based RL Agents](#deep-value-based)
# 7. [Deep Policy Based RL Agents](#deep-policy-based)
# 8. [Experiments to Run](#experiments)

# %% [markdown]
# # Provide Information
# <a id="Provide-Information"></a>

# %% [markdown]
# Name: **RITIKA**
#
# Roll No.: **230862**
#
# IITK EMail: **ritika23@iitk.ac.in**

# %% [markdown]
# # Instructions
# <a id="Instructions"></a>

# %% [markdown]
# **Read all the instructions below carefully before you start working on the assignment.**
# - The purpose of this course is that you learn RL and the best way to do that is by implementation and experimentation.
# - The assignment requires your to implement some algorithms and you are required report your findings after experimenting with those algorithms.
# - **You are required to submit this Jupyter notebook (.ipynb). The notebook would include the code, graphs/plots of the experiments you run and your findings/observations.**
# - In case you use any maths in your explanations, render it using latex in the Jupyter notebook.
# - You are expected to implement algorithms on your own and not copy it from other sources/class mates. Of course, you can refer to lecture slides.
# - If you use any reference or material (including code), please cite the source, else it will be considered plagiarism. But referring to other sources that directly solve the problems given in the assignment is not allowed. There is a limit to which you can refer to outside material.
# - This is an individual assignment.
# - In case your solution is found to have an overlap with solution by someone else (including external sources), all the parties involved will get zero in this and all future assignments plus further more penalties in the overall grade. We will check not just for lexical but also semantic overlap. Same applies for the code as well. Even an iota of cheating would NOT be tolerated. If you cheat one line or cheat one page the penalty would be same.
# - Be a smart agent, think long term, if you cheat we will discover it somehow, the price you would be paying is not worth it.
# - In case you are struggling with the assignment, seek help from TAs. Cheating is not an option! I respect honesty and would be lenient if you are not able to solve some questions due to difficulty in understanding. Remember we are there to help you out, seek help if something is difficult to understand.
# - The deadline for the submission is given above. Submit at least 30 minutes before the deadline, lot can happen at the last moment, your internet can fail, there can be a power failure, you can be abducted by aliens, etc.
# - You have to submit your assignment via the Google Form (link above)
# - The form would close after the deadline and we will not accept any solution. No reason what-so-ever would be accepted for not being able to submit before the deadline.
# - Since the assignment involves experimentation, reporting your results and observations, there is a lot of scope for creativity and innovation and presenting new perspectives. Such efforts would be highly appreciated and accordingly well rewarded. Be an exploratory agent!
# - Your code should be very well documented, there are marks for that.
# - In your plots, have a clear legend and clear lines, etc. Of course you would generating the plots in your code but you must also put these plots in your notebook.
# - For all experiments, report about the seed used in the code documentation, write about the seed used.
# - In your notebook write about all things that are not obvious from the code e.g., if you have made any assumptions, references/sources, running time, etc.
# -  **DO NOT Forget to write name, roll no and email details above**
# - **In addition to checking your code, we will be conducting one-on-one viva for the evaluation. So please make sure that you do not cheat!**
# - For each of the sub-part in the question create a new cell below the question and put your answer in there. This includes the plots as well

# %% [markdown]
# # LLM Usage Policy
#
# It is **OK** to use LLM or other sources (websites, blogs, books, etc) for:
# * Coding ancillary parts of the algorithm such as plotting graphs, etc.
# * To develop understanding of the algorithm in the case it is not clear to you
#
# It is **NOT OK** to use LLM or other sources (websites, blogs, books, etc) for:
# * Writing the code for the main parts of the algorithm especially given that I have already provided pseudo-code in the lectures. (You can use pseudo code as it is from the lecture slides)
# * For doing hyper-parameter tuning of the algorithm.
# * For doing analysis of the results and drawing conclusions about it
#
# Since RL is specialized domain, it is very straight forward to detect when someone (especially a newbie) is taking code from LLM or other sources. In case you are found to do so (even for a small part of assignment), there will be no questions asked direct zero will be awarded to you along with further penalties which will affect your final grade.
#
# Be a smart agent (remember Honesty is the best Policy), it is ok to loose a few marks than getting a zero + penalties. It is OK if you don't do all questions in the assignment which will cost you a few marks vs getting 0.
#
# **Remember that grading is relative and you are not the only one who is finding it tough!**

# %% [markdown]
# # LLM Usage Declaration
#
# It is permitted to use Large Language Models (LLMs) **only for understanding concepts, ideation, and creating initial code stubs**.
# Using an LLM to **completely solve the assignment is not allowed**.
#
# Even if an LLM is used for the permitted purposes, you **must be able to clearly explain the solution without any LLM assistance during the viva**, if called.
#
# ---
#
# ### Q1. **Which Large Language Model (LLM) did you use to complete this assignment?**
#
# > chatgpt
#
# ---
#
# ### Q2. **In which questions did you use the LLM, and how did it help you?**
# (You may extend this table by adding more rows if needed.)
#
# | Question Number / Sub-part | Used LLM? (Yes/No) | Purpose of Using LLM (e.g., ideation, explanation, code stub, grammar) | Brief Description of LLM Contribution |
# |----------------------------|--------------------|------------------------------------------------------------------------|-------------------------------------|
# | Q1                         |                    |                                                                        |                                     |
# | Q2                         |                    |                                                                        |                                     |
# | Q3                         |                    |                                                                        |                                     |
# | Q4                         |                    |                                                                        |                                     |
#
# I mainly used the LLM while working on the implementation of the DQN-based agents and debugging my code. At a few points, my code was running very slowly or not giving the expected results, and the LLM helped me spot issues like where I was placing the training step and how often I was evaluating the agent. I also took help while working on the plotting part, especially to correctly average results across multiple seeds and show them using mean and min–max curves. Apart from that, I used it occasionally to clear up small doubts about how different DQN variants work. Overall, I used it more like a guide when I got stuck, rather than relying on it for the entire solution.
#
# ---
#
# ### Q3. **Did you refer to any other sources or websites apart from the LLM and lecture slides?**
#
# If yes, please mention the source(s) clearly:
# > _Example: Research papers, blogs, documentation, textbooks, etc._
#
# ---
#
# ### Q4. **Apart from using any LLM, what was your own contribution while solving this assignment?**
#
# Briefly describe:
# - Your understanding of the concepts
# - The reasoning you applied
# - Any implementation or analysis done independently
#
# >My main contribution was in building a clear understanding of value-based reinforcement learning and translating that into a working implementation. I worked through how DQN and its variants (like Double DQN and Dueling DQN) differ, especially in how targets are computed and how the network architecture affects learning. I also spent time understanding the role of exploration strategies and replay buffers in stabilizing training. A large part of my effort went into debugging and improving the efficiency of my code. One of the biggest challenges I faced was that the training was taking an unexpectedly long time, and it was not always obvious why. I had to go through the training loop carefully, step by step, to identify issues such as where updates were happening and how often evaluation was being performed. There were also instances where the results did not look right, so I had to reason through whether the issue was in the algorithm, the hyperparameters, or the way I was handling and plotting the data.
#
#
#
#
# ---

# %% [markdown]
# # OpenAI Gym Environments
# <a id="Environment"></a>

# %%
# all imports go in here
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import time
from collections import deque

# %% [markdown]
# In this assignment we will be exploring Deep RL algorithms and for this we will be using environmentd provided by OpenAI Gym. In particualr we will be exploring "CartPole-v0" and "MountainCar-v0" environments (https://gymnasium.farama.org/environments/classic_control/ ). The code to instantiate the environments are given in the cells below. Run these cells and play with the environments to learn more details about the environments.

# %%
# Create CartPole environment
#https://gymnasium.farama.org/environments/classic_control/cart_pole/

env = gym.make('CartPole-v0')
s, info = env.reset(seed=34)
print("Observation Space = ")
print(env.observation_space)
print("Action Space = ")
print(env.action_space)
done = False
for episode in range(20):
    print("In episode {}".format(episode))
    s, info = env.reset(seed=34 + episode)
    for i in range(100):
        print(s)
        a = env.action_space.sample()
        s, r, terminated, truncated, info = env.step(a)
        done = terminated or truncated
        if done:
            print("Finished after {} timestep".format(i+1))
            break
env.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# Observation Space =
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Action Space =
# Discrete(2)
# In episode 0
# [-0.04959717  0.03721769 -0.02572576  0.01510613]
# [-0.04885282  0.23269896 -0.02542364 -0.2855813 ]
# [-0.04419884  0.03794865 -0.03113526 -0.00102396]
# [-0.04343987  0.23350297 -0.03115574 -0.30336556]
# [-0.03876981  0.42905477 -0.03722306 -0.6057092 ]
# [-0.03018872  0.23447256 -0.04933724 -0.32497913]
# [-0.02549926  0.04008653 -0.05583682 -0.04825417]
# [-0.02469753  0.23596284 -0.0568019  -0.35801822]
# [-0.01997828  0.43184435 -0.06396227 -0.66805744]
# [-0.01134139  0.23766744 -0.07732342 -0.39617974]
# [-0.00658804  0.04372286 -0.08524701 -0.12884255]
# [-0.00571358  0.23995599 -0.08782387 -0.44715565]
# [-0.00091446  0.43620342 -0.09676698 -0.7661793 ]
# [ 0.0078096   0.6325151  -0.11209057 -1.0876743 ]
# [ 0.02045991  0.8289222  -0.13384405 -1.4133219 ]
# [ 0.03703835  0.63568866 -0.1621105  -1.1652967 ]
# [ 0.04975212  0.44300458 -0.18541642 -0.92751193]
# [ 0.05861222  0.64008033 -0.20396666 -1.2722592 ]
# Finished after 18 timestep
# In episode 1
# [-0.01620504 -0.00415044  0.04350068  0.04468257]
# [-0.01628805 -0.1998683   0.04439434  0.3507668 ]
# [-0.02028542 -0.0054049   0.05140967  0.07240673]
# [-0.02039352 -0.20122474  0.05285781  0.38085622]
# [-0.02441801 -0.39705586  0.06047493  0.6897256 ]
# [-0.03235913 -0.59296256  0.07426944  1.0008173 ]
# [-0.04421838 -0.3989075   0.09428579  0.73235226]
# [-0.05219653 -0.20520614  0.10893284  0.47076967]
# [-0.05630066 -0.40168458  0.11834823  0.7957034 ]
# [-0.06433435 -0.20836838  0.1342623   0.5424707 ]
# [-0.06850171 -0.40509644  0.14511171  0.8742617 ]
# [-0.07660364 -0.60186154  0.16259694  1.2088205 ]
# [-0.08864087 -0.4091693   0.18677336  0.97118765]
# [-0.09682426 -0.21697809  0.20619711  0.7425073 ]
# Finished after 14 timestep
# In episode 2
# [-0.03193669 -0.01017632  0.03938324 -0.0096614 ]
# [-0.03214022 -0.2058403   0.03919001  0.29518268]
# [-0.03625702 -0.4014984   0.04509367  0.5999634 ]
# [-0.04428699 -0.20703538  0.05709293  0.3218184 ]

print("Observation Space = ")
print(env.observation_space)
print("Action Space = ")
print(env.action_space)
done = False
for episode in range(20):
    print("In episode {}".format(episode))
    s, info = env.reset(seed=34 + episode)
    for i in range(100):
        print(s)
        a = env.action_space.sample()
        s, r, terminated, truncated, info = env.step(a)
        done = terminated or truncated
        if done:
            print("Finished after {} timestep".format(i+1))
            break
env.close()
# Out:
# Observation Space =
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space =
# Discrete(3)
# In episode 0
# [-0.59919435  0.        ]
# [-5.9963220e-01 -4.3788075e-04]
# [-5.9950477e-01  1.2743800e-04]
# [-0.59781295  0.00169183]
# [-0.5965691   0.00124385]
# [-0.59578234  0.00078676]
# [-0.5934584   0.00232392]
# [-0.5906144   0.00284404]
# [-0.58827114  0.00234328]
# [-0.58644587  0.00182528]
# [-0.58515203  0.00129385]
# [-0.5843991   0.00075288]
# [-0.58319277  0.00120636]
# [-0.58054185  0.00265093]
# [-0.5764659   0.00407593]
# [-0.5729951   0.00347077]
# [-0.5681552   0.00483989]
# [-0.5639822   0.00417307]
# [-0.55850697  0.00547521]
# [-0.5517704   0.00673654]
# [-0.5448228   0.00694758]
# [-0.5387162   0.00610665]
# [-0.5324962   0.00621999]
# [-0.5252095   0.00728671]
# [-0.5169107   0.00829879]
# [-0.50966203  0.00724864]
# [-0.5035179   0.00614414]
# [-0.49852428  0.00499363]
# [-0.49371853  0.00480575]
# [-0.4891366   0.00458194]
# [-0.48581266  0.00332394]
# [-0.4817715   0.00404115]
# [-0.47804326  0.00372827]
# [-0.4756556   0.00238766]
# [-0.47262627  0.00302933]
# [-0.46897775  0.00364852]
# [-0.46573704  0.00324069]
# [-0.46192813  0.00380891]
# [-0.45757914  0.00434901]
# [-0.45372203  0.0038571 ]
# [-0.45038518  0.00333685]
# [-0.44759303  0.00279215]
# [-0.44636598  0.00122704]
# [-0.44471303  0.00165296]
# [-0.44364622  0.00106682]
# [-0.4441733  -0.00052709]
# [-0.44529045 -0.00111716]
# [-0.44698954 -0.00169908]
# [-0.44825816 -0.00126861]
# [-0.44908702 -0.00082886]
# [-0.45147008 -0.00238306]
# [-0.4543899  -0.00291981]
# [-0.45882505 -0.00443516]
# [-0.46474296 -0.00591791]
# [-0.4701     -0.00535704]
# [-0.47585654 -0.00575656]
# [-0.48196995 -0.0061134 ]
# [-0.48739475 -0.00542481]
# [-0.49409056 -0.0066958 ]
# [-0.5000074  -0.00591683]
# [-0.506101   -0.00609361]
# [-0.5123258  -0.00622479]
# [-0.5186351  -0.00630932]
# [-0.5239817  -0.00534655]
# [-0.53032535 -0.00634367]
# [-0.5366186  -0.00629323]
# [-0.5438142 -0.0071956]
# [-0.5498583  -0.00604408]
# [-0.5557056  -0.00584734]
# [-0.5603125  -0.00460691]
# [-0.5636446  -0.00333211]
# [-0.5676771  -0.00403249]
# [-0.57038    -0.00270287]
# [-0.5727331  -0.00235316]
# [-0.5737191  -0.00098598]
# [-0.5753306 -0.0016115]
# [-5.7555568e-01 -2.2506318e-04]
# [-0.5743926   0.00116304]
# [-5.738501e-01  5.425189e-04]
# [-0.57193214  0.00191798]
# [-0.5696529   0.00227921]
# [-0.5660294   0.00362352]
# [-0.56308854  0.00294089]
# [-0.68552953  0.00230796]
# [-0.6820543   0.00347523]
# [-0.6784349   0.00361939]
# [-0.6726955   0.00573935]
# [-0.6658749   0.00682066]
# [-0.65801924  0.00785562]
# [-0.6481826   0.00983668]
# [-0.63843316  0.00974945]
# [-0.62683934  0.01159377]
# [-0.6134836   0.01335576]
# [-0.59946185  0.01402175]
# [-0.583876    0.01558583]
# [-0.5668406   0.01703545]
# [-0.5484817   0.01835885]
# [-0.52893645  0.0195453 ]
# [-0.51035106  0.01858533]
# [-0.4928651  0.017486 ]
# [-0.47660926  0.01625582]
# [-0.46070468  0.01590457]
# [-0.44526905  0.01543566]

# %% [markdown]
# # Hyperparameters
# <a id="Hyperparameters"></a>
#
# All your hyperparameters should be stated here. We will change their value here and your code should work  accordingly.

# %%
# mention the values of all the hyperparameters (you can add more hyper-paramters as well) to be used in the entire notebook, put the values that gave the best
# performance and were finally used for the agent

gamma =0.99
epsilon =0.8 #epsolon greedy strategy
temp = 0.01#softmax strategy
delta = 1.0#huber loss
tau = 0.005#D3QN
alpha = 0.6#D3QN-PER
beta = 0.4#D3QN-PER
beta_rate =0.01 #D3QN-PER
MAX_TRAIN_EPISODES =2000
MAX_EVAL_EPISODES =1000

# additional hyperparameters needed for NFQ
epochs = 50
bufferSize = 10000
batchSize = 64
optimizerLR = 0.001

# %% [markdown]
# # Helper Functions
# <a id="helper"></a>
#
# Write all the helper functions that will be used for value-based and policy based algorithms below. In case you want to add more helper functions, please feel free to add.

# %%
def selectGreedyAction(net, state):
    #this function gets q-values via the network and selects greedy action from q-values and returns it

    #Your code goes in here
    if not isinstance(state, torch.Tensor):
        state = torch.FloatTensor(state).unsqueeze(0)
    with torch.no_grad():
        q_values = net(state)
        return q_values.argmax().item()

# %%
def selectEpsilonGreedyAction(net,  state, epsilon):
    #this function gets q-values via the network and selects an action from q-values using epsilon greedy strategy
    #and returns it
    #note this function can be used for decaying epsilon greedy strategy,
    #you would need to create a wrapper function that will handle decaying epsilon
    #you can create this wrapper in this helper function section
    #for the agents you would be implementing it would be nice to play with decaying parameter to get optimal results

    #Your code goes in here

    if not isinstance(state, torch.Tensor):
        state = torch.FloatTensor(state).unsqueeze(0)

    if random.random() < epsilon:
        return random.randrange(net(state).shape[-1])
    else:
        with torch.no_grad():
            q_values = net(state)
            return torch.argmax(q_values).item()

# %%
# Separate wrapper function for decaying epsilon
def selectDecayingEpsilonGreedyAction(net, state, episode_num, epsilon_start=1.0, epsilon_end=0.01, decay_rate=0.995):

    epsilon = epsilon_end + (epsilon_start - epsilon_end) * (decay_rate ** episode_num)


    return selectEpsilonGreedyAction(net, state, epsilon)

# %%
def selectSoftMaxAction(net, state, temp):
    #this function gets q-values via the network and selects an action from q-values using softmax strategy
    #and returns it
    #note this function can be used for decaying temperature softmax strategy,
    #you would need to create a wrapper function that will handle decaying temperature
    #you can create this wrapper in this helper function section
    #for the agents you would be implementing it would be nice to play with decaying parameter to get optimal results

    #Your code goes in here
    import numpy as np

    if not isinstance(state, torch.Tensor):
        state = torch.FloatTensor(state).unsqueeze(0)

    with torch.no_grad():
        q_values = net(state).cpu().numpy()[0]

    q_values = q_values / temp
    exp_values = np.exp(q_values - np.max(q_values))
    probabilities = exp_values / np.sum(exp_values)

    return np.random.choice(len(q_values), p=probabilities)

def selectDecayingSoftMaxAction(net, state, episode_num, temp_start=1.0, temp_end=0.01, decay_rate=0.995):
    temp = temp_end + (temp_start - temp_end) * (decay_rate ** episode_num)
    return selectSoftMaxAction(net, state, temp)

# %%
#Value Network
def createValueNetwork(inDim, outDim, hDim = [32,32], activation = F.relu):
    #this creates a Feed Forward Neural Network class and instantiates it and returns the class
    #the class should be derived from torch nn.Module and it should have init and forward method at the very least
    #the forward function should return q-value for each possible action

    #Your code goes in here
    class ValueNetwork(nn.Module):
        def __init__(self):
            super(ValueNetwork, self).__init__()
            self.output_dim = outDim
            self.activation = activation

            self.fc1 = nn.Linear(inDim, hDim[0])
            self.fc2 = nn.Linear(hDim[0], hDim[1])
            self.fc3 = nn.Linear(hDim[1], outDim)

        def forward(self, state):
            x = self.activation(self.fc1(state))
            x = self.activation(self.fc2(x))
            q_values = self.fc3(x)
            return q_values

    valueNetwork = ValueNetwork()
    return valueNetwork

# %%
#Dueling Network
def createDuelingNetwork(inDim, outDim, hDim = [32,32], activation = F.relu):
    #this creates a Feed Forward Neural Network class and instantiates it and returns the class
    #the class should be derived from torch nn.Module and it should have init and forward method at the very least
    #the forward function should return q-value which is derived
    #internally from action-advantage function and v-function,
    #Note we center the advantage values, basically we subtract the mean from each state-action value

    #Your code goes in here
    class DuelingNetwork(nn.Module):
        def __init__(self):
            super(DuelingNetwork, self).__init__()
            self.output_dim = outDim
            self.activation = activation

            self.fc1 = nn.Linear(inDim, hDim[0])
            self.fc2 = nn.Linear(hDim[0], hDim[1])

            self.value_stream = nn.Linear(hDim[1], 1)
            self.advantage_stream = nn.Linear(hDim[1], outDim)

        def forward(self, state):
            x = self.activation(self.fc1(state))
            x = self.activation(self.fc2(x))

            value = self.value_stream(x)
            advantage = self.advantage_stream(x)

            advantage_mean = advantage.mean(dim=-1, keepdim=True)
            advantage_centered = advantage - advantage_mean

            q_values = value + advantage_centered

            return q_values

    duelNetwork = DuelingNetwork()
    return duelNetwork

# %%
#Policy Network
def createPolicyNetwork(inDim, outDim, hDim = [32,32], activation = F.relu):
    #this creates a Feed Forward Neural Network class and instantiates it and returns the class
    #the class should be derived from torch nn.Module and it should have init and forward method at the very least
    #the forward function should return action logit vector
    #Your code goes in here
    class PolicyNetwork(nn.Module):
        def __init__(self):
            super(PolicyNetwork, self).__init__()
            self.output_dim = outDim
            self.activation = activation

            self.fc1 = nn.Linear(inDim, hDim[0])
            self.fc2 = nn.Linear(hDim[0], hDim[1])
            self.fc3 = nn.Linear(hDim[1], outDim)

        def forward(self, state):
            x = self.activation(self.fc1(state))
            x = self.activation(self.fc2(x))
            action_logits = self.fc3(x)
            return action_logits

    policyNetwork = PolicyNetwork()
    return policyNetwork

# %%
def plotQuantity(quantityListDict, totalEpisodeCount, descriptionList):
    #this function takes in the quantityListDict and plots quantity vs episodes.
    #quantityListListDict = {envInstanceCount: quantityList}
    #quantityList is list of the qunatity per episode,
    #for example it could be mean reward per episode, traintime per episode, etc.
    #
    #NOTE: len(quantityList) == totalEpisodeCount
    #
    #Since we run multiple instances of the environment, there will be variance across environments
    #so in the plot, you will plot per episode maximum, minimum and average value across all env instances
    #Basically, you need to envelop (e.g., via color) the quantity between max and min with mean value in between
    #
    #use the descriptionList parameter to put legends, title, etc.
    #For each of the plot, create the legend on the left/right side so that it doesn't overlay on the plot lines/envelop.
    #
    #this is a generic function and can be used to plot any of the quantity of interest
    #In particular we will be using this function to plot:
    #        mean train rewards vs episodes
    #        mean evaluation rewards vs episodes
    #        total steps vs episode
    #        train time vs episode
    #        wall clock time vs episode
    #
    #
    #this function doesn't return anything

    #Your code goes in here
    import numpy as np
    import matplotlib.pyplot as plt

    episodes = range(1, totalEpisodeCount + 1)

    all_quantities = []
    for env_instance in quantityListDict.values():
        all_quantities.append(env_instance)

    all_quantities = np.array(all_quantities)

    mean_values = np.mean(all_quantities, axis=0)
    max_values = np.max(all_quantities, axis=0)
    min_values = np.min(all_quantities, axis=0)

    plt.figure(figsize=(10, 6))

    plt.plot(episodes, mean_values, 'b-', label='Mean', linewidth=2)
    plt.fill_between(episodes, min_values, max_values, alpha=0.3, color='b', label='Min-Max Range')

    plt.xlabel('Episodes')
    plt.ylabel(descriptionList[0] if descriptionList else 'Quantity')
    plt.title(descriptionList[1] if len(descriptionList) > 1 else 'Quantity vs Episodes')

    plt.legend(loc='upper left')
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

    return

# %%
def huberLoss(error, delta):
    #this function calculates the huber loss for the error using the delta parameter

    #Your code goes in here
    abs_error = torch.abs(error)

    quadratic = 0.5 * (abs_error ** 2)
    linear = delta * (abs_error - 0.5 * delta)

    hLoss = torch.where(abs_error <= delta, quadratic, linear)
    return hLoss

# %%
import torch.nn as nn

def createQNetwork(input_dim, output_dim):
    model = nn.Sequential(
        nn.Linear(input_dim, 128),
        nn.ReLU(),
        nn.Linear(128, 128),
        nn.ReLU(),
        nn.Linear(128, output_dim)
    )

    model.output_dim = output_dim   #  ADD THIS LINE
    return model

# %%
#in case you want to create any other helper function, the code goes in here

# %%
#in case you want to create any other helper function, the code goes in here

# %% [markdown]
# # Deep Value Based RL agents
# <a id="deep-value-based"></a>
# ($50+50+50+50+50+50=300$ Marks)

# %% [markdown]
# ### The purpose of this part is to learn about different Deep Value Based RL agents.
#
# In this part of the assignment you will be implementing Deep RL algorithms we learnt in Lectures. Namely, we will be implementing NFQ, DQN, Double DQN (DDQN), Duelling Double DQN (D3QN), and Duelling Double DQN with Prioritized Experience Replay (D3QN-PER). For all the algorithms below, this time we will not be specifying the hyper-parameters, please play with the hyper-params to come up with the best values. This way you will learn to tune the model. Some of the values were specified in the lecture, that would be a good starting point. Your aim is to develop the best NFQ/DQN/DDQN/D3QN/D3QN-PER agent for each of the setting.
#
# For those of you who follow TEDEd, here is an interesting video by TED on DQN and Atari Games: https://www.youtube.com/watch?v=PP8Zc778B8s
#
# Also since these environments are available in Gymanasium, there are public leaderboards (https://github.com/openai/gym/wiki/Leaderboard) for each of these environments. Compare where does your agent stand on these leaderboard for each of these environments, try to tune your agents so that it is on the top of the leaderboard. In fact, if your agent performs well on these environments, you can alse make your entry on the leaderboard.

# %% [markdown]
# ## <font color='green'> Do not change any Class/Methods definition. We have split the class methods across cells for code readibility purposes. This requires to inherit the same class, please do not change it. </font>

# %% [markdown]
# ## ReplayBuffer (50 Marks)

# %% [markdown]
# In next few cells, you will implement replaybuffer class.
#
# This class creates a buffer for storing and retrieving experiences. This is a generic class and can be used
# for different agents like NFQ, DQN, DDQN, PER_DDQN, etc.
# Following are the methods for this class which are implemented in subsequent cells
#
# ```
# class ReplayBuffer():
#     def __init__(self, bufferSize, **kwargs)
#     def store(self, experience)
#     def update(self, indices, priorities)
#     def collectExperiences(env, state, explorationStrategy, net = None)
#     def sample(self, batchSize, **kwargs)
#     def splitExperiences(self, experiences)
#     def length(self)
# ```

# %%
class ReplayBuffer():
    def __init__(self, bufferSize, bufferType = 'DQN', **kwargs):
        # this function creates the relevant data-structures, and intializes all relevant variables
        # it can take variable number of parameters like alpha, beta, beta_rate (required for PER)
        # here the bufferType variable can be used to maintain one class for all types of agents
        # using the bufferType parameter in the methods below, you can implement all possible functionalities
        # that could be used for different types of agents
        # permissible values for bufferType = NFQ, DQN, DDQN, D3QN and PER-D3QN

        #Your code goes in here
        self.bufferSize = bufferSize
        self.bufferType = bufferType
        self.buffer = []
        self.position = 0
        self.size = 0
        if bufferType == 'D3QN_PER':
            self.alpha = kwargs.get('alpha', 0.6)
            self.beta = kwargs.get('beta', 0.4)
            self.beta_rate = kwargs.get('beta_rate', 0.001)
            self.priorities = np.zeros(bufferSize, dtype=np.float32)
            self.max_priority = 1.
        return

# %%
class ReplayBuffer(ReplayBuffer):
    def store(self, experience):
        #stores the experiences, based on parameters in init it can assign priorities, etc.
        #
        #this function does not return anything
        #
        #Your code goes in here
        state, action, reward, next_state, done = experience

        if len(self.buffer) < self.bufferSize:
            self.buffer.append(experience)
        else:
            self.buffer[self.position] = experience

        if self.bufferType == 'D3QN_PER':
            self.priorities[self.position] = self.max_priority

        self.position = (self.position + 1) % self.bufferSize
        self.size = min(self.size + 1, self.bufferSize)

        return

# %%
class ReplayBuffer(ReplayBuffer):
    def update(self, indices, priorities):
        #this is mainly used for PER-DDQN
        #otherwise just have a pass in this method
        #
        #this function does not return anything
        #
        #Your code goes in here
        if self.bufferType == 'D3QN_PER':
            for idx, priority in zip(indices, priorities):
                self.priorities[idx] = abs(priority)
                if priority > self.max_priority:
                    self.max_priority = priority
        return

# %%
class ReplayBuffer(ReplayBuffer):
    def collectExperiences(self,env, state, explorationStrategy, countExperiences, net = None):
        #this method allows the agent to interact with the environment starting from a state and it collects
        #experiences during the interaction, it uses network to get the value function and uses exploration strategy
        #to select action. It collects countExperiences and in case the environment terminates before that it returns
        #the function calling this method needs to handle early termination accordingly.
        #
        #this function does not return anything
        #
        #Your code goes in here
        current_state = state

        for _ in range(countExperiences):
            if net is not None:
                action = explorationStrategy(net, current_state)
            else:
                action = env.action_space.sample()

            next_state, reward, done, info = env.step(action)


            experience = (current_state, action, reward, next_state, done)
            self.store(experience)

            current_state = next_state

            if done:
                break

        return

# %%
class ReplayBuffer(ReplayBuffer):
    def sample(self, batchSize, **kwargs):
        # this method returns batchSize number of experiences
        # based on extra arguments, it could do sampling or it could return the latest batchSize experiences or
        # via some other strategy
        #
        # in the case of Prioritized Experience Replay (PER) the sampling needs to take into account the priorities
        #
        # this function returns experiences samples
        #
        #Your code goes in here
        if self.bufferType == 'D3QN_PER':
            beta = kwargs.get('beta', self.beta)

            priorities = self.priorities[:self.size]

            if priorities.sum() == 0:
                probs = np.ones_like(priorities) / len(priorities)
            else:
                probs = priorities / priorities.sum()

            indices = np.random.choice(self.size, batchSize, p=probs)
            samples = [self.buffer[idx] for idx in indices]

            total = self.size
            weights = (total * probs[indices]) ** (-beta)
            weights = weights / weights.max()

            experiencesList = (samples, indices, weights)

        elif self.bufferType == 'NFQ':
            indices = list(range(max(0, len(self.buffer) - batchSize), len(self.buffer)))
            experiencesList = [self.buffer[idx] for idx in indices]

        else:
            experiencesList = random.sample(self.buffer, min(batchSize, len(self.buffer)))

        return experiencesList

# %%
class ReplayBuffer(ReplayBuffer):
    def splitExperiences(self, experiences):
        #it takes in experiences and gives the following:
        #states, actions, rewards, nextStates, dones
        #
        #Your code goes in here
        #
        states = []
        actions = []
        rewards = []
        nextStates = []
        dones = []

        for exp in experiences:
            state, action, reward, nextState, done = exp
            states.append(state)
            actions.append(action)
            rewards.append(reward)
            nextStates.append(nextState)
            dones.append(done)


        states = np.array(states)
        actions = np.array(actions)
        rewards = np.array(rewards)
        nextStates = np.array(nextStates)
        dones = np.array(dones)

        return states, actions, rewards, nextStates, dones

# %%
class ReplayBuffer(ReplayBuffer):
    def length(self):
        #tells the number of experiences stored in the internal buffer
        #
        #Your code goes in here
        #

        return len(self.buffer)

# %% [markdown]
# ## Neural Fitted Q (NFQ) (50 Marks)

# %% [markdown]
# Implement the Neural Fitted Q algorithm. We have studied about NFQ algorithm in the Lecture. Use the function definitions (given below).
#
# This class implements the NFQ Agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment.
# Also please feel free to play with different exploration strategies with decaying paramters (epsilon/temperature)
#
# You may also add extra helper classes if required.
#
# You must test your implementation on both Gym environments. In the submitted Colab notebook, demonstrate the training for both environments using at least one random seed
#
# ```
# class NFQ():
#     def __init__(env, seed, gamma, epochs,
#                  bufferSize,
#                  batchSize,
#                  optimizerFn,
#                  optimizerLR,
#                  MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
#                  explorationStrategyTrainFn,
#                  explorationStrategyEvalFn)
#     def initBookKeeping(self)
#     def performBookKeeping(self, train = True)
#     def runNFQ(self)
#     def trainAgent(self)
#     def trainNetwork(self, experiences, epochs)
#     def evaluateAgent(self)
# ```

# %%
class NFQ():
    def __init__(self, env, seed, gamma, epochs,
                 bufferSize,
                 batchSize,
                 optimizerFn,
                 optimizerLR,
                 MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
                 explorationStrategyTrainFn,
                 explorationStrategyEvalFn):
        #this NFQ method
        # 1. creates and initializes (with seed) the environment, train/eval episodes, gamma, etc.
        # 2. creates and intializes all the variables required for book-keeping values via the initBookKeeping method
        # 3. creates Q-network using the createValueNetwork above
        # 4. creates and initializes (with network params) the optimizer function
        # 5. sets the explorationStartegy variables/functions for train and evaluation
        # 6. sets the batchSize for the number of experiences
        # 7. Creates the replayBuffer
        self.env = env
        self.seed = seed
        self.gamma = gamma
        self.epochs = epochs
        self.bufferSize = bufferSize
        self.batchSize = batchSize
        self.optimizerFn = optimizerFn
        self.optimizerLR = optimizerLR
        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODES = MAX_EVAL_EPISODES
        self.explorationStrategyTrainFn = explorationStrategyTrainFn
        self.explorationStrategyEvalFn = explorationStrategyEvalFn

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.inDim = env.observation_space.shape[0]
        self.outDim = env.action_space.n

        self.q_network = createValueNetwork(self.inDim, self.outDim).to(self.device)

        self.optimizer = self.optimizerFn(self.q_network.parameters(), lr=self.optimizerLR)

        self.replayBuffer = ReplayBuffer(self.bufferSize, bufferType='NFQ')

        self.initBookKeeping()

        np.random.seed(self.seed)
        torch.manual_seed(self.seed)
        random.seed(self.seed)
        self.env.action_space.seed(self.seed)
        self.env.reset(seed=self.seed)
    #Your code goes in here

# %%
class NFQ(NFQ):
    def initBookKeeping(self):
        #this method creates and intializes all the variables required for book-keeping values and it is called
        #init method
        self.train_rewards = []
        self.eval_rewards = []
        self.train_losses = []
        self.eval_losses = []
        self.train_episodes_completed = 0
        self.eval_episodes_completed = 0
        self.total_steps = 0
        self.training_time = []
        self.episode_lengths = []
        self.best_eval_reward = -float('inf')
    #Your code goes in here

# %%
class NFQ(NFQ):
    def performBookKeeping(self, train = True):
        #this method updates relevant variables for the bookKeeping, this can be called
        #multiple times during training
        #if you want you can print information using this, so it may help to monitor progress and also help to debug
        if train:
            #  Only print at FINAL training episode
            if self.train_episodes_completed == self.MAX_TRAIN_EPISODES:
                print("\n========== TRAINING COMPLETE ==========")
                print(f"Total Episodes: {self.MAX_TRAIN_EPISODES}")
                print(f"Final Train Reward: {self.train_rewards[-1]:.2f}")
                if self.train_losses:
                    print(f"Final Loss: {self.train_losses[-1]:.4f}")
                print(f"Total Steps: {self.total_steps}")

                # Optional: average over last few episodes
                avg_train = np.mean(self.train_rewards[-10:])
                print(f"Avg Train Reward (last 10): {avg_train:.2f}")

        else:
            # Only print at FINAL evaluation episode
            if self.eval_episodes_completed == self.MAX_EVAL_EPISODES:
                print("\n========== EVALUATION COMPLETE ==========")
                print(f"Total Eval Episodes: {self.MAX_EVAL_EPISODES}")
                print(f"Final Eval Reward: {self.eval_rewards[-1]:.2f}")

                avg_eval = np.mean(self.eval_rewards)
                print(f"Average Eval Reward: {avg_eval:.2f}")


    #Your code goes in here

# %%
class NFQ(NFQ):
    def runNFQ(self):
        #this is the main method, it trains the agent, performs bookkeeping while training and finally evaluates
        #the agent and returns the following quantities:
        #1. episode wise mean train rewards
        #2. epsiode wise mean eval rewards
        #2. episode wise trainTime (in seconds): time elapsed during training since the start of the first episode
        #3. episode wise wallClockTime (in seconds): actual time elapsed since the start of training,
        #                               note this will include time for BookKeeping and evaluation
        # Note both trainTime and wallClockTime get accumulated as episodes proceed.


        #Your code goes in here
        import time

        trainRewardsList = []
        trainTimeList = []
        evalRewardsList = []
        wallClockTimeList = []

        start_wall_time = time.time()
        total_train_time = 0

        for episode in range(self.MAX_TRAIN_EPISODES):
            episode_start_time = time.time()

            state, _ = self.env.reset()
            done = False
            episode_reward = 0
            episode_steps = 0

            # ------------------ DATA COLLECTION ------------------
            while not done and episode_steps < self.epochs:


                action = self.explorationStrategyTrainFn(self.q_network, state)

                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                #  store RAW numpy states
                experience = (state, action, reward, next_state, done)
                self.replayBuffer.store(experience)

                episode_reward += reward
                episode_steps += 1
                state = next_state
                self.total_steps += 1

            # ------------------ TRAINING ------------------
            if self.replayBuffer.size > 0:

                experiences = self.replayBuffer.sample(
                    min(self.batchSize, self.replayBuffer.size)
                )

                states, actions, rewards, nextStates, dones = \
                    self.replayBuffer.splitExperiences(experiences)

                #  convert properly here
                states = torch.FloatTensor(np.array(states)).to(self.device)
                actions = torch.LongTensor(actions).to(self.device)
                rewards = torch.FloatTensor(rewards).to(self.device)
                nextStates = torch.FloatTensor(np.array(nextStates)).to(self.device)
                dones = torch.FloatTensor(dones).to(self.device)


                actions = actions.unsqueeze(1)

                q_values = self.q_network(states)
                current_q_values = q_values.gather(1, actions).squeeze(1)

                with torch.no_grad():
                    next_q_values = self.q_network(nextStates).max(1)[0]
                    target_q_values = rewards + self.gamma * next_q_values * (1 - dones)

                loss = F.mse_loss(current_q_values, target_q_values)

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

                self.train_losses.append(loss.item())


            episode_time = time.time() - episode_start_time
            total_train_time += episode_time

            self.train_rewards.append(episode_reward)
            trainRewardsList.append(episode_reward)
            trainTimeList.append(total_train_time)
            wallClockTimeList.append(time.time() - start_wall_time)

            self.train_episodes_completed += 1
            self.performBookKeeping(train=True)


        for eval_episode in range(self.MAX_EVAL_EPISODES):
            state, _ = self.env.reset()
            done = False
            episode_reward = 0

            while not done:


                action = self.explorationStrategyEvalFn(self.q_network, state)

                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                episode_reward += reward
                state = next_state

            self.eval_rewards.append(episode_reward)
            evalRewardsList.append(episode_reward)
            self.eval_episodes_completed += 1
            self.performBookKeeping(train=False)

        finalEvalReward = np.mean(
            self.eval_rewards[-min(10, len(self.eval_rewards))]
        )
        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, finalEvalReward

# %%
class NFQ(NFQ):
    def trainAgent(self):
        #this method collects experiences and trains the NFQ agent and does BookKeeping while training.
        #this calls the trainNetwork() method internally, it also evaluates the agent per episode
        #it trains the agent for MAX_TRAIN_EPISODES

        #Your code goes in here
        import time

        trainRewardsList = []
        trainTimeList = []
        evalRewardsList = []
        wallClockTimeList = []

        start_wall_time = time.time()
        total_train_time = 0

        for episode in range(self.MAX_TRAIN_EPISODES):
            episode_start_time = time.time()

            state, _ = self.env.reset()
            done = False
            episode_reward = 0
            episode_steps = 0


            while not done and episode_steps < self.epochs:


                action = self.explorationStrategyTrainFn(self.q_network, state)

                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated


                experience = (state, action, reward, next_state, done)
                self.replayBuffer.store(experience)

                episode_reward += reward
                episode_steps += 1
                state = next_state
                self.total_steps += 1


            if self.replayBuffer.size > 0:
                self.trainNetwork()   # assumes this function handles tensor conversion correctly


            episode_time = time.time() - episode_start_time
            total_train_time += episode_time

            self.train_rewards.append(episode_reward)
            trainRewardsList.append(episode_reward)
            trainTimeList.append(total_train_time)

            self.train_episodes_completed += 1
            self.performBookKeeping(train=True)


            eval_reward = self.evaluateAgent()  # assumes eval handles tensor conversion
            self.eval_rewards.append(eval_reward)
            evalRewardsList.append(eval_reward)
            self.eval_episodes_completed += 1

            wallClockTimeList.append(time.time() - start_wall_time)

        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList

# %%
class NFQ(NFQ):
    def trainNetwork(self, experiences, epochs):
        # this method trains the value network epoch number of times and is called by the trainAgent function
        # it essentially uses the experiences to calculate target, using the targets it calculates the error, which
        # is further used for calulating the loss. It then uses the optimizer over the loss
        # to update the params of the network by backpropagating through the network
        # this function does not return anything
        # you can try out other loss functions other than MSE like Huber loss, MAE, etc.

        #Your code goes in here
        states, actions, rewards, nextStates, dones = self.replayBuffer.splitExperiences(experiences)

        # ----------- CONVERT ONCE (NOT INSIDE LOOP) -----------
        states = torch.FloatTensor(states).to(self.device)
        actions = torch.LongTensor(actions).unsqueeze(1).to(self.device)   # (batch_size, 1)
        rewards = torch.FloatTensor(rewards).to(self.device)
        nextStates = torch.FloatTensor(nextStates).to(self.device)
        dones = torch.FloatTensor(dones).to(self.device)

        # ----------- TRAIN FOR MULTIPLE EPOCHS -----------
        for _ in range(epochs):

            # Q(s,a)
            current_q_values = self.q_network(states).gather(1, actions).squeeze(1)

            # target = r + gamma * max Q(s', a')
            with torch.no_grad():
                next_q_values = self.q_network(nextStates).max(1)[0]
                target_q_values = rewards + self.gamma * next_q_values * (1 - dones)

            # loss
            loss = F.mse_loss(current_q_values, target_q_values)

            # optimize
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            self.train_losses.append(loss.item())

        return

# %%
class NFQ(NFQ):
    def evaluateAgent(self):
        #this function evaluates the agent using the value network, it evaluates agent for MAX_EVAL_EPISODES
        #typcially MAX_EVAL_EPISODES = 1

        #Your code goes in here
        eval_rewards = []

        for episode in range(self.MAX_EVAL_EPISODES):
            state, _ = self.env.reset()
            done = False
            episode_reward = 0

            while not done:
                #  REMOVE tensor conversion here
                action = self.explorationStrategyEvalFn(self.q_network, state)

                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                episode_reward += reward
                state = next_state

            eval_rewards.append(episode_reward)
            self.eval_episodes_completed += 1
            self.performBookKeeping(train=False)

        return np.mean(eval_rewards)

# %%
# Demonstration (Single Seed)
# Run NFQ on two Gym environments (CartPole-v0 and MountainCar-v0) for atleast one seed


# seed = 0

# env1 = gym.make(...)
# env2 = gym.make(...)

# agent1 = NFQ(env1, seed, ...)
# agent1.runNFQ()

# agent2 = NFQ(env2, seed, ...)
# agent2.runNFQ()

# %%
def run_cartpole_nfq(seed=0):
    env = gym.make("CartPole-v0")

    agent = NFQ(
        env=env,
        seed=seed,
        gamma=gamma,
        epochs=epochs,
        bufferSize=bufferSize,
        batchSize=batchSize,
        optimizerFn=optim.Adam,
        optimizerLR=optimizerLR,
        MAX_TRAIN_EPISODES=MAX_TRAIN_EPISODES,
        MAX_EVAL_EPISODES=MAX_EVAL_EPISODES,
        explorationStrategyTrainFn=lambda net, state: selectEpsilonGreedyAction(net, state, epsilon),
        explorationStrategyEvalFn=lambda net, state: selectEpsilonGreedyAction(net, state, 0)  # greedy eval
    )

    print(" Running NFQ on CartPole-v0")
    agent.runNFQ()


def run_mountaincar_nfq(seed=0):
    env = gym.make("MountainCar-v0")

    agent = NFQ(
        env=env,
        seed=seed,
        gamma=gamma,
        epochs=epochs,
        bufferSize=bufferSize,
        batchSize=batchSize,
        optimizerFn=optim.Adam,
        optimizerLR=optimizerLR,
        MAX_TRAIN_EPISODES=MAX_TRAIN_EPISODES,
        MAX_EVAL_EPISODES=MAX_EVAL_EPISODES,
        explorationStrategyTrainFn=lambda net, state: selectEpsilonGreedyAction(net, state, epsilon),
        explorationStrategyEvalFn=lambda net, state: selectEpsilonGreedyAction(net, state, 0)  # greedy eval
    )

    print("\n\n Running NFQ on MountainCar-v0")
    agent.runNFQ()

# %%
seed = 346

run_cartpole_nfq(seed)
run_mountaincar_nfq(seed)

# %% [markdown]
# ## Deep Q-Network (DQN) (50 Marks)

# %% [markdown]
# Implement the Deep Q algorithm. We have studied about DQN algorithm in the Lecture. Use the function definitions (given below).
#
# This class implements the DQN Agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment
#
# You may also add extra helper classes if required.
#
# You must test your implementation on both Gym environments. In the submitted Colab notebook, demonstrate the training for both environments using at least one random seed
#
# ```
# class DQN():
#     def __init__(env, seed, gamma,
#                  bufferSize,
#                  batchSize,
#                  optimizerFn,
#                  optimizerLR,
#                  MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
#                  explorationStrategyTrainFn,
#                  explorationStrategyEvalFn,
#                  updateFrequency)
#     def initBookKeeping(self)
#     def performBookKeeping(self, train = True)
#     def runDQN(self)
#     def trainAgent(self)
#     def trainNetwork(self, experiences)
#     def updateNetwork(self, onlineNet, targetNet)
#     def evaluateAgent(self)
# ```

# %%
class DQN():
    def __init__(self, env, seed, gamma,
                 bufferSize,
                 batchSize,
                 optimizerFn,
                 optimizerLR,
                 MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
                 explorationStrategyTrainFn,
                 explorationStrategyEvalFn,
                 updateFrequency):
        #this DQN method
        # 1. creates and initializes (with seed) the environment, train/eval episodes, gamma, etc.
        # 2. creates and intializes all the variables required for book-keeping values via the initBookKeeping method
        # 3. creates traget and online Q-networks using the createValueNetwork above
        # 4. creates and initializes (with network params) the optimizer function
        # 5. sets the explorationStartegy variables/functions for train and evaluation
        # 6. sets the batchSize for the number of experiences
        # 7. Creates the replayBuffer

        #Your code goes in here
        self.env = env
        self.env.reset(seed=seed)
        torch.manual_seed(seed)
        np.random.seed(seed)
        random.seed(seed)

        self.gamma = gamma
        self.batchSize = batchSize
        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODES = MAX_EVAL_EPISODES
        self.updateFrequency = updateFrequency

        self.explorationStrategyTrainFn = explorationStrategyTrainFn
        self.explorationStrategyEvalFn = explorationStrategyEvalFn

        obs_dim = env.observation_space.shape[0]
        action_dim = env.action_space.n

        self.q_online = createQNetwork(obs_dim, action_dim)
        self.q_target = createQNetwork(obs_dim, action_dim)

        self.updateNetwork(self.q_online, self.q_target)

        self.optimizer = optimizerFn(self.q_online.parameters(), lr=optimizerLR)

        self.replayBuffer = ReplayBuffer(bufferSize)

        self.initBookKeeping()

# %%
class DQN(DQN):
    def initBookKeeping(self):
        #this method creates and intializes all the variables required for book-keeping values and it is called
        #init method
        #
        # Your code goes in here
        #
        self.train_rewards = []
        self.eval_rewards = []
        self.train_losses = []
        self.eval_losses = []
        self.train_episodes_completed = 0
        self.eval_episodes_completed = 0
        self.total_steps = 0
        self.training_time = []
        self.episode_lengths = []
        self.best_eval_reward = -float('inf')
        return

# %%
class DQN(DQN):
    def performBookKeeping(self, train = True):
        #this method updates relevant variables for the bookKeeping, this can be called
        #multiple times during training
        #if you want you can print information using this, so it may help to monitor progress and also help to debug
        #
        # Your code goes in here
        #
        if train:
            #  print only at final training episode
            if self.train_episodes_completed == self.MAX_TRAIN_EPISODES:
                print("\n===== TRAINING COMPLETE =====")
                print("Final Train Reward:", self.train_rewards[-1])

                if len(self.train_rewards) >= 10:
                    print("Avg Train Reward (last 10):",
                          np.mean(self.train_rewards[-10:]))

        else:
            #  print only at final evaluation episode
            if self.eval_episodes_completed == self.MAX_EVAL_EPISODES:
                print("\n===== EVALUATION COMPLETE =====")
                print("Final Eval Reward:", self.eval_rewards[-1])
                print("Average Eval Reward:",
                      np.mean(self.eval_rewards))

        return

# %%
class DQN(DQN):
    def runDQN(self):
        #this is the main method, it trains the agent, performs bookkeeping while training and finally evaluates
        #the agent and returns the following quantities:
        #1. episode wise mean train rewards
        #2. epsiode wise mean eval rewards
        #2. episode wise trainTime (in seconds): time elapsed during training since the start of the first episode
        #3. episode wise wallClockTime (in seconds): actual time elapsed since the start of training,
        #                               note this will include time for BookKeeping and evaluation
        # Note both trainTime and wallClockTime get accumulated as episodes proceed.
        #
        #Your code goes in here
        #
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList = self.trainAgent()
        finalEvalReward = np.mean(evalRewardsList[-min(10, len(evalRewardsList)):])

        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, finalEvalReward

# %%
class DQN(DQN):
    def trainAgent(self):
        #this method collects experiences and trains the agent and does BookKeeping while training.
        #this calls the trainNetwork() method internally, it also evaluates the agent per episode
        #it trains the agent for MAX_TRAIN_EPISODES
        #
        #Your code goes in here
        #
        trainRewardsList = []
        evalRewardsList = []
        trainTimeList = []
        wallClockTimeList = []

        start_wall = time.time()
        total_train_time = 0

        for episode in range(self.MAX_TRAIN_EPISODES):

            episode_start = time.time()

            state, _ = self.env.reset()
            done = False
            episode_reward = 0

            while not done:

                state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
                action = self.explorationStrategyTrainFn(self.q_online, state_tensor)

                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                # store experience
                self.replayBuffer.store((state, action, reward, next_state, done))

                #  TRAIN INSIDE LOOP
                if self.replayBuffer.size >= self.batchSize:
                    experiences = self.replayBuffer.sample(self.batchSize)
                    self.trainNetwork(experiences, 1)

                state = next_state
                episode_reward += reward
                self.total_steps += 1

            # update target network
            if episode % self.updateFrequency == 0:
                self.updateNetwork(self.q_online, self.q_target)

            # bookkeeping
            self.train_rewards.append(episode_reward)
            trainRewardsList.append(episode_reward)

            total_train_time += (time.time() - episode_start)
            trainTimeList.append(total_train_time)
            wallClockTimeList.append(time.time() - start_wall)

            self.performBookKeeping(train=True)

            #  EVALUATE LESS FREQUENTLY
            if episode % 10 == 0:
                eval_reward = self.evaluateAgent()
            else:
                eval_reward = evalRewardsList[-1] if len(evalRewardsList) > 0 else 0

            evalRewardsList.append(eval_reward)


        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList

# %%
class DQN(DQN):
    def trainNetwork(self, experiences, epochs):
        # this method trains the value network epoch number of times and is called by the trainAgent function
        # it essentially uses the experiences to calculate target, using the targets it calculates the error, which
        # is further used for calulating the loss. It then uses the optimizer over the loss
        # to update the params of the network by backpropagating through the network
        # this function does not return anything
        # you can try out other loss functions other than MSE like Huber loss, MAE, etc.
        #
        #Your code goes in here
        #
        import torch
        import torch.nn.functional as F

        for _ in range(epochs):

            states, actions, rewards, next_states, dones = self.replayBuffer.splitExperiences(experiences)

            states = torch.tensor(states, dtype=torch.float32)
            actions = torch.tensor(actions, dtype=torch.long)
            rewards = torch.tensor(rewards, dtype=torch.float32)
            next_states = torch.tensor(next_states, dtype=torch.float32)
            dones = torch.tensor(dones, dtype=torch.float32)

            q_values = self.q_online(states).gather(1, actions.unsqueeze(1)).squeeze(1)

            with torch.no_grad():
                max_next_q = self.q_target(next_states).max(1)[0]
                targets = rewards + self.gamma * max_next_q * (1 - dones)

            loss = F.mse_loss(q_values, targets)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

        return

# %%
class DQN(DQN):
    def updateNetwork(self, onlineNet, targetNet):
        #this function updates the onlineNetwork with the target network
        #
        # Your code goes in here
        #
        targetNet.load_state_dict(onlineNet.state_dict())

        return

# %%
class DQN(DQN):
    def evaluateAgent(self):
        #this function evaluates the agent using the value network, it evaluates agent for MAX_EVAL_EPISODES
        #typcially MAX_EVAL_EPISODES = 1
        #
        #Your code goes in here
        #
        import numpy as np
        import torch

        rewards = []

        for _ in range(self.MAX_EVAL_EPISODES):

            state, _ = self.env.reset()
            done = False
            total_reward = 0

            while not done:

                state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)

                with torch.no_grad():  #  IMPORTANT
                    action = self.explorationStrategyEvalFn(self.q_online, state_tensor)

                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                total_reward += reward
                state = next_state

            rewards.append(total_reward)

        return np.mean(rewards)

# %%
# --- Set seed ---
seed = 346

# --- Create environments ---
env1 = gym.make("CartPole-v0")
env2 = gym.make("MountainCar-v0")

# --- Hyperparameters (use your tuned values if you have them) ---
gamma = 0.99
bufferSize = 10000
batchSize = 64
optimizerLR = 1e-3
MAX_TRAIN_EPISODES = 5000
MAX_EVAL_EPISODES = 500
updateFrequency = 10
epsilon = 0.1

# --- DDQN Agents ---
agent1 = DQN(
    env1,
    seed,
    gamma,
    bufferSize,
    batchSize,
    optim.Adam,
    optimizerLR,
    MAX_TRAIN_EPISODES,
    MAX_EVAL_EPISODES,
    lambda net, state: selectEpsilonGreedyAction(net, state, epsilon),
    lambda net, state: selectEpsilonGreedyAction(net, state, 0),
    updateFrequency
)

agent2 = DQN(
    env2,
    seed,
    gamma,
    bufferSize,
    batchSize,
    optim.Adam,
    optimizerLR,
    MAX_TRAIN_EPISODES,
    MAX_EVAL_EPISODES,
    lambda net, state: selectEpsilonGreedyAction(net, state, epsilon),
    lambda net, state: selectEpsilonGreedyAction(net, state, 0),
    updateFrequency
)

# --- Run DDQN ---
print("Running DDQN on CartPole")
results_cartpole = agent1.runDQN()

print("\nRunning DDQN on MountainCar")
results_mountaincar = agent2.runDQN()

# %%
# Demonstration
# Run DQN on two Gym environments(CartPole-v0 and MountainCar-v0) for atleast one seed


# seed = 0

# env1 = gym.make(...)
# env2 = gym.make(...)

# agent1 = DQN(env1, seed, ...)
# agent1.runDQN()

# agent2 = DQN(env2, seed, ...)
# agent2.runDQN()

# %% [markdown]
# ## Double DQN (DDQN) (50 Marks)

# %% [markdown]
# Implement the Double DQN agent. We have studied about Double DQN agent in the Lecture. Use the function definitions (given below).
#
# This class implements the Double DQN agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment
#
# You may also add extra helper classes if required.
#
# You must test your implementation on both Gym environments. In the submitted Colab notebook, demonstrate the training for both environments using at least one random seed
#
# ```
# class DDQN():
#     def __init__(env, seed, gamma,
#                  bufferSize,
#                  batchSize,
#                  optimizerFn,
#                  optimizerLR,
#                  MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
#                  explorationStrategyTrainFn,
#                  explorationStrategyEvalFn,
#                  updateFrequency)
#     def initBookKeeping(self)
#     def performBookKeeping(self, train = True)
#     def runDDQN(self)
#     def trainAgent(self)
#     def trainNetwork(self, experiences)
#     def updateNetwork(self, onlineNet, targetNet)
#     def evaluateAgent(self)
# ```

# %%
class DDQN():
    def __init__(self, env, seed, gamma,
                 bufferSize,
                 batchSize,
                 optimizerFn,
                 optimizerLR,
                 MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
                 explorationStrategyTrainFn,
                 explorationStrategyEvalFn,
                 updateFrequency):
        #this DDQN method
        # 1. creates and initializes (with seed) the environment, train/eval episodes, gamma, etc.
        # 2. creates and intializes all the variables required for book-keeping values via the initBookKeeping method
        # 3. creates tareget and online Q-networks using the createValueNetwork above
        # 4. creates and initializes (with network params) the optimizer function
        # 5. sets the explorationStartegy variables/functions for train and evaluation
        # 6. sets the batchSize for the number of experiences
        # 7. Creates the replayBuffer

        #Your code goes in here
        self.env = env
        self.seed = seed
        self.gamma = gamma
        self.bufferSize = bufferSize
        self.batchSize = batchSize
        self.optimizerFn = optimizerFn
        self.optimizerLR = optimizerLR
        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODES = MAX_EVAL_EPISODES
        self.explorationStrategyTrainFn = explorationStrategyTrainFn
        self.explorationStrategyEvalFn = explorationStrategyEvalFn
        self.updateFrequency = updateFrequency

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.inDim = env.observation_space.shape[0]
        self.outDim = env.action_space.n

        self.online_network = createValueNetwork(self.inDim, self.outDim)
        self.target_network = createValueNetwork(self.inDim, self.outDim)
        self.target_network.load_state_dict(self.online_network.state_dict())

        self.optimizer = self.optimizerFn(self.online_network.parameters(), lr=self.optimizerLR)

        self.replayBuffer = ReplayBuffer(self.bufferSize, bufferType='DDQN')

        self.initBookKeeping()

        np.random.seed(self.seed)
        torch.manual_seed(self.seed)
        random.seed(self.seed)
        self.env.action_space.seed(self.seed)
        self.env.reset(seed=self.seed)

# %%
class DDQN(DDQN):
    def initBookKeeping(self):
        #this method creates and intializes all the variables required for book-keeping values and it is called
        #init method
        #
        # Your code goes in here
        #
        self.train_rewards = []
        self.eval_rewards = []
        self.train_losses = []
        self.train_episodes_completed = 0
        self.eval_episodes_completed = 0
        self.total_steps = 0
        self.training_time = []
        self.episode_lengths = []
        self.best_eval_reward = -float('inf')
        self.update_counter = 0
        self.reward_window = deque(maxlen=100)

        return

# %%
class DDQN(DDQN):
    def performBookKeeping(self, train = True):
        #this method updates relevant variables for the bookKeeping, this can be called
        #multiple times during training
        #if you want you can print information using this, so it may help to monitor progress and also help to debug
        #
        # Your code goes in here
        #
        if train:
            #  print only at final training episode
            if self.train_episodes_completed == self.MAX_TRAIN_EPISODES:
                print("\n===== TRAINING COMPLETE =====")
                print("Final Train Reward:", self.train_rewards[-1])

                if len(self.train_rewards) >= 10:
                    print("Avg Train Reward (last 10):",
                          np.mean(self.train_rewards[-10:]))

        else:
            #  print only at final evaluation episode
            if self.eval_episodes_completed == self.MAX_EVAL_EPISODES:
                print("\n===== EVALUATION COMPLETE =====")
                print("Final Eval Reward:", self.eval_rewards[-1])
                print("Average Eval Reward:",
                      np.mean(self.eval_rewards))

        return

# %%
class DDQN(DDQN):
    def runDDQN(self):
        #this is the main method, it trains the agent, performs bookkeeping while training and finally evaluates
        #the agent and returns the following quantities:
        #1. episode wise mean train rewards
        #2. epsiode wise mean eval rewards
        #2. episode wise trainTime (in seconds): time elapsed during training since the start of the first episode
        #3. episode wise wallClockTime (in seconds): actual time elapsed since the start of training,
        #                               note this will include time for BookKeeping and evaluation
        # Note both trainTime and wallClockTime get accumulated as episodes proceed.

        #Your code goes in here
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList = self.trainAgent()

        finalEvalReward = np.mean(self.eval_rewards[-min(10, len(self.eval_rewards)):])

        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, finalEvalReward

# %%
class DDQN(DDQN):
    def trainAgent(self):
        #this method collects experiences and trains the agent and does BookKeeping while training.
        #this calls the trainNetwork() method internally, it also evaluates the agent per episode
        #it trains the agent for MAX_TRAIN_EPISODES
        #
        #Your code goes in here
        trainRewardsList = []
        trainTimeList = []
        evalRewardsList = []
        wallClockTimeList = []

        start_wall_time = time.time()
        total_train_time = 0

        for episode in range(self.MAX_TRAIN_EPISODES):
            episode_start_time = time.time()

            state, _ = self.env.reset()
            done = False
            episode_reward = 0
            episode_steps = 0

            while not done:
                action = self.explorationStrategyTrainFn(self.online_network, state)
                next_state, reward, done, _, _ = self.env.step(action)

                experience = (state, action, reward, next_state, done)
                self.replayBuffer.store(experience)

                episode_reward += reward
                episode_steps += 1
                state = next_state
                self.total_steps += 1
                self.update_counter += 1

                if len(self.replayBuffer.buffer) >= self.batchSize:
                    experiences = self.replayBuffer.sample(self.batchSize)
                    self.trainNetwork(experiences, epochs=1)

                if self.update_counter % self.updateFrequency == 0:
                    self.updateNetwork(self.online_network, self.target_network)

            episode_time = time.time() - episode_start_time
            total_train_time += episode_time

            self.train_rewards.append(episode_reward)
            trainRewardsList.append(episode_reward)
            trainTimeList.append(total_train_time)
            wallClockTimeList.append(time.time() - start_wall_time)

            self.train_episodes_completed += 1
            self.reward_window.append(episode_reward)
            self.performBookKeeping(train=True)

            eval_rewards = self.evaluateAgent()
            avg_eval_reward = np.mean(eval_rewards)
            self.eval_rewards.append(avg_eval_reward)
            evalRewardsList.append(avg_eval_reward)


        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList

# %%
class DDQN(DDQN):
    def trainNetwork(self, experiences, epochs):
        # this method trains the value network epoch number of times and is called by the trainAgent function
        # it essentially uses the experiences to calculate target, using the targets it calculates the error, which
        # is further used for calulating the loss. It then uses the optimizer over the loss
        # to update the params of the network by backpropagating through the network
        # this function does not return anything
        # you can try out other loss functions other than MSE like Huber loss, MAE, etc.
        #
        #Your code goes in here
        states, actions, rewards, nextStates, dones = self.replayBuffer.splitExperiences(experiences)

        states = torch.FloatTensor(np.array(states))
        actions = torch.LongTensor(actions).unsqueeze(1)
        rewards = torch.FloatTensor(rewards).unsqueeze(1)
        nextStates = torch.FloatTensor(np.array(nextStates))
        dones = torch.FloatTensor(dones).unsqueeze(1)

        for epoch in range(epochs):
            current_q_values = self.online_network(states).gather(1, actions)

            with torch.no_grad():
                argmax_actions = self.online_network(nextStates).max(1)[1].unsqueeze(1)
                max_next_q_values = self.target_network(nextStates).gather(1, argmax_actions)
                target_q_values = rewards + self.gamma * max_next_q_values * (1 - dones)

            td_errors = target_q_values - current_q_values

            loss = F.mse_loss(current_q_values, target_q_values)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            self.train_losses.append(loss.item())

        return

# %%
class DDQN(DDQN):
    def updateNetwork(self, onlineNet, targetNet):
        #this function updates the onlineNetwork with the target network
        #
        # Your code goes in here
        #
        targetNet.load_state_dict(onlineNet.state_dict())

        return

# %%
class DDQN(DDQN):
    def evaluateAgent(self):
        #this function evaluates the agent using the value network, it evaluates agent for MAX_EVAL_EPISODES
        #typcially MAX_EVAL_EPISODES = 1

        #Your code goes in here
        eval_rewards = []

        for episode in range(self.MAX_EVAL_EPISODES):
            state, _ = self.env.reset()
            done = False
            episode_reward = 0

            while not done:
                action = self.explorationStrategyEvalFn(self.online_network, state)
                next_state, reward, done, _, _ = self.env.step(action)
                episode_reward += reward
                state = next_state

            eval_rewards.append(episode_reward)
            self.eval_episodes_completed += 1

        return eval_rewards

        #return finalEvalRewardsList

# %%
# Demonstration
# Run DDQN on two Gym environments(CartPole-v0 and MountainCar-v0) for  atleast one seed


# seed = 0

# env1 = gym.make(...)
# env2 = gym.make(...)

# agent1 = DDQN(env1, seed, ...)
# agent1.runDDQN()

# agent2 = DDQN(env2, seed, ...)
# agent2.runDDQN()

# %%
seed = 346

print("CartPole-v0")
env1 = gym.make('CartPole-v0')
env1.reset(seed=seed)

agent1 = DDQN(
    env=env1,
    seed=seed,
    gamma=0.99,
    bufferSize=10000,
    batchSize=64,
    optimizerFn=optim.Adam,
    optimizerLR=0.001,
    MAX_TRAIN_EPISODES=200,
    MAX_EVAL_EPISODES=5,
    explorationStrategyTrainFn=lambda net, state: selectEpsilonGreedyAction(net, state, epsilon=0.1),
    explorationStrategyEvalFn=lambda net, state: selectGreedyAction(net, state),
    updateFrequency=100
)

train_rewards1, train_time1, eval_rewards1, wall_time1, final_eval1 = agent1.runDDQN()
print(f"Final Eval Reward: {final_eval1:.2f}")

print("\nMountainCar-v0")
env2 = gym.make('MountainCar-v0')
env2.reset(seed=seed)

agent2 = DDQN(
    env=env2,
    seed=seed,
    gamma=0.99,
    bufferSize=10000,
    batchSize=64,
    optimizerFn=optim.Adam,
    optimizerLR=0.001,
    MAX_TRAIN_EPISODES=300,
    MAX_EVAL_EPISODES=5,
    explorationStrategyTrainFn=lambda net, state: selectEpsilonGreedyAction(net, state, epsilon=0.1),
    explorationStrategyEvalFn=lambda net, state: selectGreedyAction(net, state),
    updateFrequency=100
)

train_rewards2, train_time2, eval_rewards2, wall_time2, final_eval2 = agent2.runDDQN()
print(f"Final Eval Reward: {final_eval2:.2f}")

env1.close()
env2.close()

# %% [markdown]
# ## Dueling DDQN (50 Marks)

# %% [markdown]
# Implement the Dueling Double Deep Q algorithm. We have studied about Dueling Double DQN agent in the Lecture. Use the function definitions (given below).
#
# This class implements the Dueling Double DQN agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment
#
# You may also add extra helper classes if required.
#
# You must test your implementation on both Gym environments. In the submitted Colab notebook, demonstrate the training for both environments using at least one random seed
#
# ```
# class D3QN():
#     def __init__(env, seed, gamma, tau,
#                  bufferSize,
#                  batchSize,
#                  optimizerFn,
#                  optimizerLR,
#                  MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
#                  explorationStrategyTrainFn,
#                  explorationStrategyEvalFn,
#                  updateFrequency)
#     def initBookKeeping(self)
#     def performBookKeeping(self, train = True)
#     def runD3QN(self)
#     def trainAgent(self)
#     def trainNetwork(self, experiences)
#     def updateNetwork(self, onlineNet, targetNet)
#     def evaluateAgent(self)
# ```

# %%
class D3QN():
    def __init__(self,env, seed, gamma, tau,
                 bufferSize,
                 batchSize,
                 optimizerFn,
                 optimizerLR,
                 MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
                 explorationStrategyTrainFn,
                 explorationStrategyEvalFn,
                 updateFrequency):
        #this D3QN method
        # 1. creates and initializes (with seed) the environment, train/eval episodes, gamma, batch size,MAX_TRAIN_EPISODES,MAX_EVAL_EPISODES,updateFrequency etc.
        # 2. creates and intializes all the variables required for book-keeping values via the initBookKeeping method
        # 3. creates target and online Q-networks using the createDuelingNetwork above
        # 4. creates and initializes (with network params) the optimizer function
        # 5. sets the explorationStartegy variables/functions for train and evaluation
        # 6. sets the batchSize for the number of experiences
        # 7. Creates the replayBuffer

        #Your code goes in here
        self.env = env
        self.seed = seed
        self.gamma = gamma
        self.tau = tau
        self.bufferSize = bufferSize
        self.batchSize = batchSize
        self.optimizerFn = optimizerFn
        self.optimizerLR = optimizerLR
        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODES = MAX_EVAL_EPISODES
        self.explorationStrategyTrainFn = explorationStrategyTrainFn
        self.explorationStrategyEvalFn = explorationStrategyEvalFn
        self.updateFrequency = updateFrequency

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.inDim = env.observation_space.shape[0]
        self.outDim = env.action_space.n

        self.online_network = createDuelingNetwork(self.inDim, self.outDim)
        self.target_network = createDuelingNetwork(self.inDim, self.outDim)
        self.target_network.load_state_dict(self.online_network.state_dict())

        self.optimizer = self.optimizerFn(self.online_network.parameters(), lr=self.optimizerLR)

        self.replayBuffer = ReplayBuffer(self.bufferSize, bufferType='D3QN')

        self.initBookKeeping()

        np.random.seed(self.seed)
        torch.manual_seed(self.seed)
        random.seed(self.seed)
        self.env.action_space.seed(self.seed)
        self.env.reset(seed=self.seed)

# %%
class D3QN(D3QN):
    def initBookKeeping(self):
        #this method creates and intializes all the variables required for book-keeping values and it is called
        #init method
        #
        # Your code goes in here
        #
        self.train_rewards = []
        self.eval_rewards = []
        self.train_losses = []
        self.train_episodes_completed = 0
        self.eval_episodes_completed = 0
        self.total_steps = 0
        self.training_time = []
        self.episode_lengths = []
        self.best_eval_reward = -float('inf')
        self.update_counter = 0
        self.reward_window = deque(maxlen=100)

        return

# %%
class D3QN(D3QN):
    def performBookKeeping(self, train = True):
        #this method updates relevant variables for the bookKeeping, this can be called
        #multiple times during training
        #if you want you can print information using this, so it may help to monitor progress and also help to debug
        #
        # Your code goes in here
        #
        if train:
            #  print only at final training episode
            if self.train_episodes_completed == self.MAX_TRAIN_EPISODES:
                print("\n===== TRAINING COMPLETE =====")
                print("Final Train Reward:", self.train_rewards[-1])

                if len(self.train_rewards) >= 10:
                    print("Avg Train Reward (last 10):",
                          np.mean(self.train_rewards[-10:]))

        else:
            #  print only at final evaluation episode
            if self.eval_episodes_completed == self.MAX_EVAL_EPISODES:
                print("\n===== EVALUATION COMPLETE =====")
                print("Final Eval Reward:", self.eval_rewards[-1])
                print("Average Eval Reward:",
                      np.mean(self.eval_rewards))

        return

# %%
class D3QN(D3QN):
    def runD3QN(self):
        #this is the main method, it trains the agent, performs bookkeeping while training and finally evaluates
        #the agent and returns the following quantities:
        #1. episode wise mean train rewards
        #2. epsiode wise mean eval rewards
        #2. episode wise trainTime (in seconds): time elapsed during training since the start of the first episode
        #3. episode wise wallClockTime (in seconds): actual time elapsed since the start of training,
        #                               note this will include time for BookKeeping and evaluation
        # Note both trainTime and wallClockTime get accumulated as episodes proceed.

        #Your code goes in here
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList = self.trainAgent()

        finalEvalReward = np.mean(self.eval_rewards[-min(10, len(self.eval_rewards)):])

        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, finalEvalReward

# %%
class D3QN(D3QN):
    def trainAgent(self):
        #this method collects experiences and trains the agent and does BookKeeping while training.
        #this calls the trainNetwork() method internally, it also evaluates the agent per episode
        #it trains the agent for MAX_TRAIN_EPISODES

        #Your code goes in here
        trainRewardsList = []
        trainTimeList = []
        evalRewardsList = []
        wallClockTimeList = []

        start_wall_time = time.time()
        total_train_time = 0

        for episode in range(self.MAX_TRAIN_EPISODES):
            episode_start_time = time.time()

            state, _ = self.env.reset()
            done = False
            episode_reward = 0
            episode_steps = 0

            while not done:
                action = self.explorationStrategyTrainFn(self.online_network, state)
                next_state, reward, done, _, _ = self.env.step(action)

                experience = (state, action, reward, next_state, done)
                self.replayBuffer.store(experience)

                episode_reward += reward
                episode_steps += 1
                state = next_state
                self.total_steps += 1
                self.update_counter += 1

                if len(self.replayBuffer.buffer) >= self.batchSize:
                    experiences = self.replayBuffer.sample(self.batchSize)
                    self.trainNetwork(experiences, epochs=1)

                if self.update_counter % self.updateFrequency == 0:
                    self.updateNetwork(self.online_network, self.target_network)

            episode_time = time.time() - episode_start_time
            total_train_time += episode_time

            self.train_rewards.append(episode_reward)
            trainRewardsList.append(episode_reward)
            trainTimeList.append(total_train_time)
            wallClockTimeList.append(time.time() - start_wall_time)

            self.train_episodes_completed += 1
            self.reward_window.append(episode_reward)
            self.performBookKeeping(train=True)

            eval_rewards = self.evaluateAgent()
            avg_eval_reward = np.mean(eval_rewards)
            self.eval_rewards.append(avg_eval_reward)
            evalRewardsList.append(avg_eval_reward)

        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList

# %%
class D3QN(D3QN):
    def trainNetwork(self, experiences, epochs):
        # this method trains the value network epoch number of times and is called by the trainAgent function
        # it essentially uses the experiences to calculate target, using the targets it calculates the error, which
        # is further used for calulating the loss. It then uses the optimizer over the loss
        # to update the params of the network by backpropagating through the network
        # this function does not return anything
        # you can try out other loss functions other than MSE like Huber loss, MAE, etc.

        #Your code goes in here
        states, actions, rewards, nextStates, dones = self.replayBuffer.splitExperiences(experiences)

        states = torch.FloatTensor(np.array(states))
        actions = torch.LongTensor(actions).unsqueeze(1)
        rewards = torch.FloatTensor(rewards).unsqueeze(1)
        nextStates = torch.FloatTensor(np.array(nextStates))
        dones = torch.FloatTensor(dones).unsqueeze(1)

        for epoch in range(epochs):
            current_q_values = self.online_network(states).gather(1, actions)

            with torch.no_grad():
                argmax_actions = self.online_network(nextStates).max(1)[1].unsqueeze(1)
                max_next_q_values = self.target_network(nextStates).gather(1, argmax_actions)
                target_q_values = rewards + self.gamma * max_next_q_values * (1 - dones)

            td_errors = target_q_values - current_q_values

            loss = F.mse_loss(current_q_values, target_q_values)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            self.train_losses.append(loss.item())


        return

# %%
class D3QN(D3QN):
    def updateNetwork(self, onlineNet, targetNet):
        #this function updates the onlineNetwork with the target network using Polyak averaging
        #
        # Your code goes in here
        #
        for target_param, online_param in zip(targetNet.parameters(), onlineNet.parameters()):
            target_param.data.copy_(self.tau * online_param.data + (1.0 - self.tau) * target_param.data)


        return

# %%
class D3QN(D3QN):
    def evaluateAgent(self):
        #this function evaluates the agent using the value network, it evaluates agent for MAX_EVAL_EPISODES
        #typcially MAX_EVAL_EPISODES = 1
        #
        #Your code goes in here
        eval_rewards = []

        for episode in range(self.MAX_EVAL_EPISODES):
            state, _ = self.env.reset()
            done = False
            episode_reward = 0

            while not done:
                action = self.explorationStrategyEvalFn(self.online_network, state)
                next_state, reward, done, _, _ = self.env.step(action)
                episode_reward += reward
                state = next_state

            eval_rewards.append(episode_reward)
            self.eval_episodes_completed += 1

        return eval_rewards

        #return finalEvalRewardsList

# %%
# Demonstration
# Run D3QN on two Gym environments(CartPole-v0 and MountainCar-v0) for atleast one seed


# seed = 0

# env1 = gym.make(...)
# env2 = gym.make(...)

# agent1 = D3QN(env1, seed, ...)
# agent1.runD3QN()

# agent2 = D3QN(env2, seed, ...)
# agent2.runD3QN()

# %%
seed = 42

print("CartPole-v1")
env1 = gym.make('CartPole-v1')

agent1 = D3QN(
    env=env1,
    seed=seed,
    gamma=0.99,
    tau=0.005,
    bufferSize=10000,
    batchSize=64,
    optimizerFn=optim.Adam,
    optimizerLR=0.001,
    MAX_TRAIN_EPISODES=200,
    MAX_EVAL_EPISODES=5,
    explorationStrategyTrainFn=lambda net, state: selectEpsilonGreedyAction(net, state, epsilon=0.1),
    explorationStrategyEvalFn=lambda net, state: selectGreedyAction(net, state),
    updateFrequency=100
)

_, _, _, _, final1 = agent1.runD3QN()
print(f"Final: {final1:.2f}\n")

print("MountainCar-v0")
env2 = gym.make('MountainCar-v0')

agent2 = D3QN(
    env=env2,
    seed=seed,
    gamma=0.99,
    tau=0.005,
    bufferSize=10000,
    batchSize=64,
    optimizerFn=optim.Adam,
    optimizerLR=0.001,
    MAX_TRAIN_EPISODES=300,
    MAX_EVAL_EPISODES=5,
    explorationStrategyTrainFn=lambda net, state: selectEpsilonGreedyAction(net, state, epsilon=0.1),
    explorationStrategyEvalFn=lambda net, state: selectGreedyAction(net, state),
    updateFrequency=100
)

_, _, _, _, final2 = agent2.runD3QN()
print(f"Final: {final2:.2f}")

env1.close()
env2.close()

# %% [markdown]
# ## Dueling Double Deep Q Network with Prioritized Experience Replay (D3QN-PER) (50 Marks)

# %% [markdown]
# Implement the Dueling Double DQN with Prioritized Experience Replay (D3QN-PER) agent. We have studied about D3QN-PER agent in the Lecture. Use the function definitions (given below).
#
# This class implements the D3QN-PER agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment
#
# You may also add extra helper classes if required.
#
# You must test your implementation on both Gym environments. In the submitted Colab notebook, demonstrate the training for both environments using at least one random seed
#
# ```
# class D3QN_PER():
#     def __init__(env, seed, gamma, tau, alpha, beta, beta_rate,
#                  bufferSize,
#                  batchSize,
#                  optimizerFn,
#                  optimizerLR,
#                  MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
#                  explorationStrategyTrainFn,
#                  explorationStrategyEvalFn,
#                  updateFrequency)
#     def initBookKeeping(self)
#     def performBookKeeping(self, train = True)
#     def runD3QN_PER(self)
#     def trainAgent(self)
#     def trainNetwork(self, experiences)
#     def updateNetwork(self, onlineNet, targetNet)
#     def evaluateAgent(self)
# ```

# %%
class D3QN_PER():
    def __init__(self, env, seed, gamma, tau, alpha, beta, beta_rate,
                 bufferSize,
                 batchSize,
                 optimizerFn,
                 optimizerLR,
                 MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
                 explorationStrategyTrainFn,
                 explorationStrategyEvalFn,
                 updateFrequency):
        #this D3QN method
        # 1. creates and initializes (with seed) the environment, train/eval episodes, gamma, etc.
        # 2. creates and intializes all the variables required for book-keeping values via the initBookKeeping method
        # 3. creates tareget and online Q-networks using the createValueNetwork above
        # 4. creates and initializes (with network params) the optimizer function
        # 5. sets the explorationStartegy variables/functions for train and evaluation
        # 6. sets the batchSize for the number of experiences
        # 7. Creates the replayBuffer,
        #    the replayBuffer takes the parameters bufferSize, alpha, beta and beta_rate
        #
        # Your code goes in here
        self.env = env
        self.env.reset(seed=seed)
        torch.manual_seed(seed)
        np.random.seed(seed)
        random.seed(seed)

        self.gamma = gamma
        self.tau = tau
        self.batchSize = batchSize
        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODES = MAX_EVAL_EPISODES
        self.updateFrequency = updateFrequency

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.explorationStrategyTrainFn = explorationStrategyTrainFn
        self.explorationStrategyEvalFn = explorationStrategyEvalFn

        obs_dim = env.observation_space.shape[0]
        action_dim = env.action_space.n

        self.online_network = createDuelingNetwork(obs_dim, action_dim).to(self.device)
        self.target_network = createDuelingNetwork(obs_dim, action_dim).to(self.device)

        self.target_network.load_state_dict(self.online_network.state_dict())
        self.target_network.eval()

        self.optimizer = optimizerFn(self.online_network.parameters(), lr=optimizerLR)

        self.replayBuffer = ReplayBuffer(bufferSize)

        self.initBookKeeping()

# %%
class D3QN_PER(D3QN_PER):
    def initBookKeeping(self):
        #this method creates and intializes all the variables required for book-keeping values and it is called
        #init method
        #
        #Your code goes in here
        #
        self.train_rewards = []
        self.eval_rewards = []
        self.train_losses = []
        self.train_episodes_completed = 0
        self.eval_episodes_completed = 0
        self.total_steps = 0
        self.update_counter = 0
        return

# %%
class D3QN_PER(D3QN_PER):
    def performBookKeeping(self, train = True):
        #this method updates relevant variables for the bookKeeping, this can be called
        #multiple times during training
        #if you want you can print information using this, so it may help to monitor progress and also help to debug
        #
        #Your code goes in here
        #
        if train:
            if self.train_episodes_completed == self.MAX_TRAIN_EPISODES:
                print("\n===== D3QN TRAINING COMPLETE =====")
                print(f"Final Train Reward: {self.train_rewards[-1]:.2f}")
                if len(self.train_rewards) >= 10:
                    print(f"Avg Train Reward (last 10): {np.mean(self.train_rewards[-10:]):.2f}")
        else:
            if self.eval_episodes_completed == self.MAX_EVAL_EPISODES:
                print("\n===== D3QN EVALUATION COMPLETE =====")
                print(f"Final Eval Reward: {self.eval_rewards[-1]:.2f}")
                print(f"Average Eval Reward: {np.mean(self.eval_rewards):.2f}")
        return

# %%
class D3QN_PER(D3QN_PER):
    def runD3QN_PER(self):
        #this is the main method, it trains the agent, performs bookkeeping while training and finally evaluates
        #the agent and returns the following quantities:
        #1. episode wise mean train rewards
        #2. epsiode wise mean eval rewards
        #2. episode wise trainTime (in seconds): time elapsed during training since the start of the first episode
        #3. episode wise wallClockTime (in seconds): actual time elapsed since the start of training,
        #                               note this will include time for BookKeeping and evaluation
        # Note both trainTime and wallClockTime get accumulated as episodes proceed.
        #
        # Your code goes in here
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList = self.trainAgent()
        finalEvalReward = np.mean(evalRewardsList[-min(10, len(evalRewardsList)):])

        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, finalEvalReward

# %%
class D3QN_PER(D3QN_PER):
    def trainAgent(self):
        #this method collects experiences and trains the agent and does BookKeeping while training.
        #this calls the trainNetwork() method internally, it also evaluates the agent per episode
        #it trains the agent for MAX_TRAIN_EPISODES
        #
        #Your code goes in here
        import time

        trainRewardsList = []
        evalRewardsList = []
        trainTimeList = []
        wallClockTimeList = []

        start_wall = time.time()
        total_train_time = 0

        for episode in range(self.MAX_TRAIN_EPISODES):
            episode_start = time.time()

            state, _ = self.env.reset()
            done = False
            episode_reward = 0

            while not done:
                action = self.explorationStrategyTrainFn(self.online_network, state)

                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                self.replayBuffer.store((state, action, reward, next_state, done))

                state = next_state
                episode_reward += reward
                self.total_steps += 1
                self.update_counter += 1

                if self.replayBuffer.size >= self.batchSize:
                    experiences = self.replayBuffer.sample(self.batchSize)
                    self.trainNetwork(experiences)

                if self.update_counter % self.updateFrequency == 0:
                    self.updateNetwork(self.online_network, self.target_network)

            episode_time = time.time() - episode_start
            total_train_time += episode_time

            self.train_rewards.append(episode_reward)
            trainRewardsList.append(episode_reward)
            trainTimeList.append(total_train_time)
            wallClockTimeList.append(time.time() - start_wall)

            self.train_episodes_completed += 1
            self.performBookKeeping(train=True)

            eval_reward = self.evaluateAgent()
            self.eval_rewards.append(eval_reward)
            evalRewardsList.append(eval_reward)
            self.eval_episodes_completed += 1


        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList

# %%
class D3QN_PER(D3QN_PER):
    def trainNetwork(self, experiences):
        # this method trains the value network epoch number of times and is called by the trainAgent function
        # it essentially uses the experiences to calculate target, using the targets it calculates the error, which
        # is further used for calulating the loss. It then uses the optimizer over the loss
        # to update the params of the network by backpropagating through the network
        # this function does not return anything
        # you can try out other loss functions other than MSE like Huber loss, MAE, etc.
        #
        #Your code goes in here
        states, actions, rewards, nextStates, dones = self.replayBuffer.splitExperiences(experiences)

        states = torch.FloatTensor(states).to(self.device)
        actions = torch.LongTensor(actions).unsqueeze(1).to(self.device)
        rewards = torch.FloatTensor(rewards).to(self.device)
        nextStates = torch.FloatTensor(nextStates).to(self.device)
        dones = torch.FloatTensor(dones).to(self.device)

        current_q = self.online_network(states).gather(1, actions).squeeze(1)

        with torch.no_grad():
            argmax_actions = self.online_network(nextStates).max(1)[1].unsqueeze(1)
            next_q = self.target_network(nextStates).gather(1, argmax_actions).squeeze(1)
            targets = rewards + self.gamma * next_q * (1 - dones)

        loss = F.mse_loss(current_q, targets)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.train_losses.append(loss.item())

        return

# %%
class D3QN_PER(D3QN_PER):
    def updateNetwork(self, onlineNet, targetNet):
        #this function updates the onlineNetwork with the target network using Polyak averaging \
        #
        # Your code goes in here
        #
        for target_param, online_param in zip(targetNet.parameters(), onlineNet.parameters()):
            target_param.data.copy_(self.tau * online_param.data + (1 - self.tau) * target_param.data)

        return

# %%
class D3QN_PER(D3QN_PER):
    def evaluateAgent(self):
        #this function evaluates the agent using the value network, it evaluates agent for MAX_EVAL_EPISODES
        #typcially MAX_EVAL_EPISODES = 1
        #
        #Your code goes in here
        eval_rewards = []

        for _ in range(self.MAX_EVAL_EPISODES):
            state, _ = self.env.reset()
            done = False
            episode_reward = 0

            while not done:
                action = self.explorationStrategyEvalFn(self.online_network, state)

                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                episode_reward += reward
                state = next_state

            eval_rewards.append(episode_reward)

        return np.mean(eval_rewards)

        return finalEvalRewardsList

# %%
# Demonstration
# Run D3QN_PER on two Gym environments(CartPole-v0 and MountainCar-v0) for atleast one seed


# seed = 0

# env1 = gym.make(...)
# env2 = gym.make(...)

# agent1 = D3QN_PER(env1, seed, ...)
# agent1.runD3QN_PER()

# agent2 = D3QN_PER(env2, seed, ...)
# agent2.runD3QN_PER()

# %% [markdown]
# # Experiments and Plots  ($40 \times 5 = 200$ Marks [CartPole] $40 \times 5 = 200$ Marks [MountainCar])
# <a id="experiments"></a>

# %% [markdown]
# Run the NFQ, DQN, Double DQN, Dueling Double DQN, and Dueling Double Deep Q Network with Prioritized Experience Replay on CartPole environment and MountainCar enviroment.
#
# Plot the following for each of the environment separately. Note based on different hyper-parameters and stratgies you use, can you have multiple plots for each of the below.
#
# As you are aware from your past experience, single run of the agent over the environment results in plots that have lot of variance and look very noisy. One way to overcome this is to create several different instances of the environment using different seeds and then average out the results across these and plot these. For all the plots below, you this strategy. **You need to run 5 different instances of the environment for each agent**. As you have seen in the lecture slides, we plot the maximum and minimum values around the mean in the plots, so this gives us the shaded plot with the mean curve in the between. In this assignment, you are required to do the same. Generate plots with envelop between maximum and minimum value (check the plotQuantity() function in the helper functions).
#
# For each of the quantity of interest, plot each of the agent within the same plot using different colors for the envelop. Choose colors such that that there is clear contrast between the plots corresponding to different agents.
#
# 1. Plot mean train rewards vs episodes for Cartpole environment.
# 2. Plot mean train rewards vs episodes for MountatinCar environment.
# 3. Plot mean evaluation rewards vs episodes for Cartpole environment.
# 4. Plot mean evaluation rewards vs episodes for MountainCar environment.
# 5. Plot total steps vs episode for Cartpole environment.
# 6. Plot total steps vs episode for MountatinCar environment.
# 7. Plot train time vs episode for Cartpole environment.
# 8. Plot train time vs episode for MountatinCar environment.
# 9. Plot wall clock time vs episode for Cartpole environment.
# 10. Plot wall clock time vs episode for MountatinCar environment.

# %%
def runDeepValueBasedAgents():
    # this function will initialize 5 different instances of the env (using different seeds), run all the agents
    # over these different instances. Collects results and generate the plots state above.
    # generate your plots in the cells below
    # write the answers to part 11, 12 and 13 in the cells below the plot-cells.
    import numpy as np
    import gymnasium as gym
    import matplotlib.pyplot as plt
    import pickle
    import os

    seeds = [346, 347, 348, 349, 350]

    envs = {
        "CartPole": "CartPole-v0",
        "MountainCar": "MountainCar-v0"
    }

    agents = {
        "NFQ": NFQ,
        "DQN": DQN,
        "DDQN": DDQN,
        "DuelingDDQN": D3QN,
        "DuelingDDQN_PER":D3QN_PER
    }

    results_file = "deep_value_based_results.pkl"

    all_results = {}
    if os.path.exists(results_file):
        print(f"Loading existing results from {results_file}")
        with open(results_file, 'rb') as f:
            all_results = pickle.load(f)
    else:
        for env_name in envs.keys():
            all_results[env_name] = {}
            for agent_name in agents.keys():
                all_results[env_name][agent_name] = []

    for env_name, env_id in envs.items():
        print(f"\n===== Running on {env_name} =====")

        for agent_name, AgentClass in agents.items():
            print(f"\n--- Agent: {agent_name} ---")

            completed_seeds = len(all_results[env_name][agent_name])
            print(f"Completed seeds: {completed_seeds}/{len(seeds)}")

            if completed_seeds >= len(seeds):
                print("Already completed all seeds, skipping...")
                # Plot immediately for already completed agent
                plot_single_agent_results(all_results, env_name, agent_name)
                continue

            # Run remaining seeds for this agent
            for seed_idx in range(completed_seeds, len(seeds)):
                seed = seeds[seed_idx]
                print(f"Seed: {seed}")

                env = gym.make(env_id)

                # Create agent based on type
                if agent_name == "NFQ":
                    agent = AgentClass(
                        env=env,
                        seed=seed,
                        gamma=0.99,
                        epochs=50,
                        bufferSize=50000,
                        batchSize=64,
                        optimizerFn=torch.optim.Adam,
                        optimizerLR=1e-3,
                        MAX_TRAIN_EPISODES=2000,
                        MAX_EVAL_EPISODES=1000,
                        explorationStrategyTrainFn=explorationStrategyTrainFn,
                        explorationStrategyEvalFn=explorationStrategyEvalFn
                    )

                elif agent_name in ["DuelingDDQN", "DuelingDDQN_PER"]:
                    if agent_name == "DuelingDDQN_PER":
                        agent = AgentClass(
                            env=env,
                            seed=seed,
                            gamma=0.99,
                            tau=0.005,
                            alpha=0.6,
                            beta=0.4,
                            beta_rate=0.001,
                            bufferSize=50000,
                            batchSize=64,
                            optimizerFn=torch.optim.Adam,
                            optimizerLR=1e-3,
                            MAX_TRAIN_EPISODES=2000,
                            MAX_EVAL_EPISODES=1000,
                            explorationStrategyTrainFn=explorationStrategyTrainFn,
                            explorationStrategyEvalFn=explorationStrategyEvalFn,
                            updateFrequency=10
                        )
                    else:
                        agent = AgentClass(
                            env=env,
                            seed=seed,
                            gamma=0.99,
                            tau=0.005,
                            bufferSize=50000,
                            batchSize=64,
                            optimizerFn=torch.optim.Adam,
                            optimizerLR=1e-3,
                            MAX_TRAIN_EPISODES=2000,
                            MAX_EVAL_EPISODES=1000,
                            explorationStrategyTrainFn=explorationStrategyTrainFn,
                            explorationStrategyEvalFn=explorationStrategyEvalFn,
                            updateFrequency=10
                        )

                else:  # DQN and DDQN
                    agent = AgentClass(
                        env=env,
                        seed=seed,
                        gamma=0.99,
                        bufferSize=50000,
                        batchSize=64,
                        optimizerFn=torch.optim.Adam,
                        optimizerLR=1e-3,
                        MAX_TRAIN_EPISODES=2000,
                        MAX_EVAL_EPISODES=1000,
                        explorationStrategyTrainFn=explorationStrategyTrainFn,
                        explorationStrategyEvalFn=explorationStrategyEvalFn,
                        updateFrequency=10
                    )

                # Run appropriate training method
                if agent_name == "NFQ":
                    results = agent.runNFQ()
                elif agent_name == "DDQN":
                    results = agent.runDDQN()
                elif agent_name == "DuelingDDQN":
                    results = agent.runD3QN()
                elif agent_name == "DuelingDDQN_PER":
                    results = agent.runD3QN_PER()
                else:  # DQN
                    results = agent.runDQN()

                all_results[env_name][agent_name].append(results)

                with open(results_file, 'wb') as f:
                    pickle.dump(all_results, f)
                print(f"Results saved to {results_file}")

                env.close()

            # ===== PLOT IMMEDIATELY AFTER THIS AGENT COMPLETES ALL SEEDS =====
            print(f"\n>>> {agent_name} completed all seeds! Plotting results...")
            plot_single_agent_results(all_results, env_name, agent_name)

    print(f"\nAll results saved in {results_file}")


def plot_single_agent_results(all_results, env_name, agent_name):
    """Plot results for a single agent immediately after it completes"""
    import matplotlib.pyplot as plt
    import numpy as np

    print(f"\n===== Plotting {agent_name} results for {env_name} =====")

    seed_results = all_results[env_name][agent_name]

    if len(seed_results) == 0:
        print(f"No results for {agent_name}")
        return

    # Define plot configurations
    plot_configs = [
        {"index": 0, "ylabel": "Train Reward", "title": f"{agent_name} - Train Rewards"},
        {"index": 2, "ylabel": "Evaluation Reward", "title": f"{agent_name} - Evaluation Rewards"},
        {"index": 1, "ylabel": "Train Time (seconds)", "title": f"{agent_name} - Training Time"},
        {"index": 3, "ylabel": "Wall Clock Time (seconds)", "title": f"{agent_name} - Wall Clock Time"}
    ]

    for config in plot_configs:
        plt.figure(figsize=(10, 6))

        # Extract the quantity
        quantity_list = []
        for r in seed_results:
            try:
                val = r[config["index"]]
                quantity_list.append(val)
            except:
                continue

        if len(quantity_list) == 0:
            plt.close()
            continue

        # Find minimum length across all seeds for this agent
        min_length = min(len(q) for q in quantity_list)

        # Truncate all sequences to minimum length
        truncated_quantities = []
        for q in quantity_list:
            truncated_quantities.append(q[:min_length])

        quantity = np.array(truncated_quantities)

        mean = np.mean(quantity, axis=0)
        min_val = np.min(quantity, axis=0)
        max_val = np.max(quantity, axis=0)

        episodes = np.arange(len(mean))

        plt.plot(episodes, mean, label=f"{agent_name} (n={len(seed_results)})", linewidth=2)
        plt.fill_between(episodes, min_val, max_val, alpha=0.3)

        plt.title(f"{env_name} - {config['title']} vs Episodes")
        plt.xlabel("Episodes")
        plt.ylabel(config['ylabel'])
        plt.legend()
        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.show()
        plt.pause(0.1)  # Force display
        print(f"✓ Plotted {config['title']} for {agent_name}")

# %%
# Define exploration strategies
def explorationStrategyTrainFn(net, state):
    return selectEpsilonGreedyAction(net, state, epsilon=0.1)

def explorationStrategyEvalFn(net, state):
    return selectGreedyAction(net, state)

# %%
runDeepValueBasedAgents()
# Out:
# ===== Running on CartPole =====
#
# --- Agent: NFQ ---
# Completed seeds: 0/5
# Seed: 346
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# ========== TRAINING COMPLETE ==========
# Total Episodes: 2000
# Final Train Reward: 17.00
# Final Loss: 48.9652
# Total Steps: 57852
# Avg Train Reward (last 10): 16.30
#
# ========== EVALUATION COMPLETE ==========
# Total Eval Episodes: 1000
# Final Eval Reward: 14.00
# Average Eval Reward: 16.41
# Results saved to deep_value_based_results.pkl
# Seed: 347
#
# ========== TRAINING COMPLETE ==========
# Total Episodes: 2000
# Final Train Reward: 50.00
# Final Loss: 0.2025
# Total Steps: 69848
# Avg Train Reward (last 10): 50.00
#
# ========== EVALUATION COMPLETE ==========
# Total Eval Episodes: 1000
# Final Eval Reward: 200.00
# Average Eval Reward: 198.27
# Results saved to deep_value_based_results.pkl
# Seed: 348
#
# ========== TRAINING COMPLETE ==========
# Total Episodes: 2000
# Final Train Reward: 50.00
# Final Loss: 0.0199
# Total Steps: 71660
# Avg Train Reward (last 10): 50.00
#
# ========== EVALUATION COMPLETE ==========
# Total Eval Episodes: 1000
# Final Eval Reward: 106.00
# Average Eval Reward: 94.54
# Results saved to deep_value_based_results.pkl
# Seed: 349
#
# ========== TRAINING COMPLETE ==========
# Total Episodes: 2000
# Final Train Reward: 39.00
# Final Loss: 0.1314
# Total Steps: 73800
# Avg Train Reward (last 10): 46.10
#
# ========== EVALUATION COMPLETE ==========
# Total Eval Episodes: 1000
# Final Eval Reward: 41.00
# Average Eval Reward: 56.58
# Results saved to deep_value_based_results.pkl
# Seed: 350
#
# ========== TRAINING COMPLETE ==========
# Total Episodes: 2000
# Final Train Reward: 50.00
# Final Loss: 0.2211
# Total Steps: 65945
# Avg Train Reward (last 10): 50.00
#
# ========== EVALUATION COMPLETE ==========
# Total Eval Episodes: 1000
# Final Eval Reward: 66.00
# Average Eval Reward: 179.54
# Results saved to deep_value_based_results.pkl
#
# >>> NFQ completed all seeds! Plotting results...
#
# ===== Plotting NFQ results for CartPole =====
# ✓ Plotted NFQ - Train Rewards for NFQ
# ✓ Plotted NFQ - Evaluation Rewards for NFQ
# ✓ Plotted NFQ - Training Time for NFQ
# ✓ Plotted NFQ - Wall Clock Time for NFQ
#
# --- Agent: DQN ---
# Completed seeds: 0/5
# Seed: 346
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_576/787145277.py in <cell line: 0>()
# ----> 1 runDeepValueBasedAgents()
#
# /tmp/ipykernel_576/3509692401.py in runDeepValueBasedAgents()
#     140                     results = agent.runD3QN_PER()
#     141                 else:  # DQN
# --> 142                     results = agent.runDQN()
#     143
#     144                 all_results[env_name][agent_name].append(results)
#
# /tmp/ipykernel_576/2273124039.py in runDQN(self)
#      12         #Your code goes in here
#      13         #
# ---> 14         trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList = self.trainAgent()
#      15         finalEvalReward = np.mean(evalRewardsList[-min(10, len(evalRewardsList)):])
#      16
#
# /tmp/ipykernel_576/3819062486.py in trainAgent(self)
#      51             self.performBookKeeping(train=True)
#      52
# ---> 53             eval_reward = self.evaluateAgent()
#      54             evalRewardsList.append(eval_reward)
#      55
#
# /tmp/ipykernel_576/721202242.py in evaluateAgent(self)
#      15             while not done:
#      16                 state_tensor = torch.FloatTensor(state).unsqueeze(0)
# ---> 17                 action = self.explorationStrategyEvalFn(self.q_online, state_tensor)
#      18
#      19                 next_state, reward, terminated, truncated, _ = self.env.step(action)
#
# /tmp/ipykernel_576/2246662242.py in explorationStrategyEvalFn(net, state)
#       4
#       5 def explorationStrategyEvalFn(net, state):
# ----> 6     return selectGreedyAction(net, state)
#
# /tmp/ipykernel_576/3296414909.py in selectGreedyAction(net, state)
#       6         state = torch.FloatTensor(state).unsqueeze(0)
#       7     with torch.no_grad():
# ----> 8         q_values = net(state)
#       9         return q_values.argmax().item()
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     251         """
#     252         for module in self:
# --> 253             input = module(input)
#     254         return input
#     255
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py in forward(self, input)
#     141         Runs the forward pass.
#     142         """
# --> 143         return F.relu(input, inplace=self.inplace)
#     144
#     145     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py in relu(input, inplace)
#    1719         result = torch.relu_(input)
#    1720     else:
# -> 1721         result = torch.relu(input)
#    1722     return result
#    1723
#
# KeyboardInterrupt:

# %%
def runDeepValueBasedAgents():

    import numpy as np
    import gymnasium as gym
    import matplotlib.pyplot as plt

    seeds = [0, 1, 2, 3, 4]

    envs = {
        "CartPole": "CartPole-v1",
        "MountainCar": "MountainCar-v0"
    }

    agents = {
        "NFQ": NFQ,
        "DQN": DQN,
        "DDQN": DDQN,
        "DuelingDDQN": D3QN,
        "DuelingDDQN_PER": D3QN_PER
    }

    colors = ['blue', 'red', 'green', 'orange', 'purple']

    for env_name, env_id in envs.items():

        print(f"\n===== Running on {env_name} =====")

        # -------- CREATE 4 FIGURES --------
        plt.figure(1, figsize=(10,6))
        plt.figure(2, figsize=(10,6))
        plt.figure(3, figsize=(10,6))
        plt.figure(4, figsize=(10,6))

        for agent_idx, (agent_name, AgentClass) in enumerate(agents.items()):

            print(f"\n--- Agent: {agent_name} ---")

            train_rewards_dict = {}
            eval_rewards_dict = {}
            train_time_dict = {}
            wall_clock_dict = {}

            for i, seed in enumerate(seeds):

                print(f"Seed: {seed}")

                env = gym.make(env_id)

                # -------- INIT AGENT --------
                if agent_name == "NFQ":
                    agent = AgentClass(
                        env=env, seed=seed, gamma=0.99,
                        epochs=50,
                        bufferSize=50000,
                        batchSize=64,
                        optimizerFn=torch.optim.Adam,
                        optimizerLR=1e-3,
                        MAX_TRAIN_EPISODES=2000,
                        MAX_EVAL_EPISODES=2000,
                        explorationStrategyTrainFn=explorationStrategyTrainFn,
                        explorationStrategyEvalFn=explorationStrategyEvalFn
                    )
                else:
                    agent = AgentClass(
                        env=env, seed=seed, gamma=0.99,
                        bufferSize=50000,
                        batchSize=64,
                        optimizerFn=torch.optim.Adam,
                        optimizerLR=1e-3,
                        MAX_TRAIN_EPISODES=2000,
                        MAX_EVAL_EPISODES=2000,
                        explorationStrategyTrainFn=explorationStrategyTrainFn,
                        explorationStrategyEvalFn=explorationStrategyEvalFn,
                        updateFrequency=10
                    )

                # -------- RUN --------
                if agent_name == "NFQ":
                    results = agent.runNFQ()
                elif agent_name == "DDQN":
                    results = agent.runDDQN()
                elif agent_name == "DuelingDDQN":
                    results = agent.runD3QN()
                elif agent_name == "DuelingDDQN_PER":
                    results = agent.runD3QN_PER()
                else:
                    results = agent.runDQN()

                # -------- CLEAN + STORE --------
                def clean(x):
                    x = np.array(x)
                    if x.ndim > 1:
                        x = x.flatten()
                    return x

                train_rewards_dict[i] = clean(results[0])
                train_time_dict[i]   = clean(results[1])
                eval_rewards_dict[i] = clean(results[2])
                wall_clock_dict[i]   = clean(results[3])

                env.close()

            total_episodes = len(train_rewards_dict[0])
            color = colors[agent_idx]

            # -------- ADD TO SAME PLOTS --------
            plt.figure(1)
            plotQuantity(train_rewards_dict, total_episodes, color, agent_name)

            plt.figure(2)
            plotQuantity(eval_rewards_dict, total_episodes, color, agent_name)

            plt.figure(3)
            plotQuantity(train_time_dict, total_episodes, color, agent_name)

            plt.figure(4)
            plotQuantity(wall_clock_dict, total_episodes, color, agent_name)

        # -------- FINALIZE PLOTS --------

        titles = [
            "Train Reward",
            "Evaluation Reward",
            "Train Time",
            "Wall Clock Time"
        ]

        for i, title in enumerate(titles, start=1):
            plt.figure(i)
            plt.xlabel("Episodes")
            plt.ylabel(title)
            plt.title(f"{env_name} - {title}")
            plt.legend()
            plt.grid(alpha=0.3)
            plt.show()

# %%
runDeepValueBasedAgents()
# Out:
# ===== Running on CartPole =====
#
# --- Agent: NFQ ---
# Seed: 0
#
# ========== TRAINING COMPLETE ==========
# Total Episodes: 2000
# Final Train Reward: 50.00
# Final Loss: 0.0368
# Total Steps: 68621
# Avg Train Reward (last 10): 50.00
#
# ========== EVALUATION COMPLETE ==========
# Total Eval Episodes: 2000
# Final Eval Reward: 127.00
# Average Eval Reward: 143.52
# Seed: 1
#
# ========== TRAINING COMPLETE ==========
# Total Episodes: 2000
# Final Train Reward: 10.00
# Final Loss: 2058.1812
# Total Steps: 62858
# Avg Train Reward (last 10): 10.10
#
# ========== EVALUATION COMPLETE ==========
# Total Eval Episodes: 2000
# Final Eval Reward: 10.00
# Average Eval Reward: 9.31
# Seed: 2
#
# ========== TRAINING COMPLETE ==========
# Total Episodes: 2000
# Final Train Reward: 50.00
# Final Loss: 0.0783
# Total Steps: 70155
# Avg Train Reward (last 10): 50.00
#
# ========== EVALUATION COMPLETE ==========
# Total Eval Episodes: 2000
# Final Eval Reward: 238.00
# Average Eval Reward: 237.59
# Seed: 3
#
# ========== TRAINING COMPLETE ==========
# Total Episodes: 2000
# Final Train Reward: 50.00
# Final Loss: 0.2049
# Total Steps: 66191
# Avg Train Reward (last 10): 50.00
#
# ========== EVALUATION COMPLETE ==========
# Total Eval Episodes: 2000
# Final Eval Reward: 62.00
# Average Eval Reward: 63.23
# Seed: 4
#
# ========== TRAINING COMPLETE ==========
# Total Episodes: 2000
# Final Train Reward: 12.00
# Final Loss: 4839.8818
# Total Steps: 60485
# Avg Train Reward (last 10): 9.90
#
# ========== EVALUATION COMPLETE ==========
# Total Eval Episodes: 2000
# Final Eval Reward: 10.00
# Average Eval Reward: 9.36
#
# --- Agent: DQN ---
# Seed: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_576/787145277.py in <cell line: 0>()
# ----> 1 runDeepValueBasedAgents()
#
# /tmp/ipykernel_576/804667976.py in runDeepValueBasedAgents()
#      85                     results = agent.runD3QN_PER()
#      86                 else:
# ---> 87                     results = agent.runDQN()
#      88
#      89                 # -------- CLEAN + STORE --------
#
# /tmp/ipykernel_576/2273124039.py in runDQN(self)
#      12         #Your code goes in here
#      13         #
# ---> 14         trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList = self.trainAgent()
#      15         finalEvalReward = np.mean(evalRewardsList[-min(10, len(evalRewardsList)):])
#      16
#
# /tmp/ipykernel_576/3819062486.py in trainAgent(self)
#      51             self.performBookKeeping(train=True)
#      52
# ---> 53             eval_reward = self.evaluateAgent()
#      54             evalRewardsList.append(eval_reward)
#      55
#
# /tmp/ipykernel_576/721202242.py in evaluateAgent(self)
#      15             while not done:
#      16                 state_tensor = torch.FloatTensor(state).unsqueeze(0)
# ---> 17                 action = self.explorationStrategyEvalFn(self.q_online, state_tensor)
#      18
#      19                 next_state, reward, terminated, truncated, _ = self.env.step(action)
#
# /tmp/ipykernel_576/2246662242.py in explorationStrategyEvalFn(net, state)
#       4
#       5 def explorationStrategyEvalFn(net, state):
# ----> 6     return selectGreedyAction(net, state)
#
# /tmp/ipykernel_576/3296414909.py in selectGreedyAction(net, state)
#       6         state = torch.FloatTensor(state).unsqueeze(0)
#       7     with torch.no_grad():
# ----> 8         q_values = net(state)
#       9         return q_values.argmax().item()
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     251         """
#     252         for module in self:
# --> 253             input = module(input)
#     254         return input
#     255
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py in forward(self, input)
#     141         Runs the forward pass.
#     142         """
# --> 143         return F.relu(input, inplace=self.inplace)
#     144
#     145     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py in relu(input, inplace)
#    1719         result = torch.relu_(input)
#    1720     else:
# -> 1721         result = torch.relu(input)
#    1722     return result
#    1723
#
# KeyboardInterrupt:

# %% [markdown]
# # Discussion Questions ($40 \times 3 = 120$ Marks)

# %% [markdown]
# Q 11. Based on plots for CartPole environment, what are your observations about different agents. Compare different agents.

# %% [markdown]
# SOLUTION to question 11
#
# The use of LLMs for writing this part is strictly prohibited.
#  If it is found that you have used an LLM, the TA will call you for a viva and 0 marks will be given for the whole implementation part if you are not able to justify your answer.
#   Even the use of LLMs for structuring the answer is not allowed, so write your observations and comparison in your own words based on the plots generated by your experiments
#
#   write your solution -------

# %% [markdown]
# Q12. Based on plots for MountainCar environment, what are your observations about different agents. Compare different agents. Do these observations concur with the ones for CartPole environment?

# %% [markdown]
# SOLUTION to question 12
#
# The use of LLMs for writing this part is strictly prohibited.
#  If it is found that you have used an LLM, the TA will call you for a viva and 0 marks will be given for the whole implementation part if you are not able to justify your answer.
#   Even the use of LLMs for structuring the answer is not allowed, so write your observations and comparison in your own words based on the plots generated by your experiments
#
#   write your solution -------

# %% [markdown]
# Q 13. Based on both the environments, can you generalize some of the findings for the value-based agents? If yes what are those findings?

# %% [markdown]
# SOLUTION to question 13
#
# The use of LLMs for writing this part is strictly prohibited.
#  If it is found that you have used an LLM, the TA will call you for a viva and 0 marks will be given for the whole implementation part if you are not able to justify your answer.
#   Even the use of LLMs for structuring the answer is not allowed, so write your observations and comparison in your own words based on the plots generated by your experiments
#
#   write your solution -------
